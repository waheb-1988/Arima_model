# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline
from math import sqrt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
# Analysis imports
from pandas.plotting import lag_plot
from pylab import rcParams
from statsmodels.tsa.seasonal import seasonal_decompose
import pathlib
import os
#https://medium.com/analytics-vidhya/time-series-forecasting-sarima-vs-auto-arima-models-f95e76d71d8f
# Out:
# c:\Users\ASUS TUF\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
dir_path = pathlib.Path.cwd().parent
folder_path = dir_path / "data" / "building_france_prediction" 
file_name = "departement_6.xlsx"
df= pd.read_excel(os.path.join(folder_path, file_name),parse_dates=['Date'],index_col='Date')
print(df)
# Out:
#             Day Mont  Year  transactions_6
# Date
# 2018-07-01  Sun  Jul  2018               0
# 2018-07-02  Mon  Jul  2018             156
# 2018-07-03  Tue  Jul  2018             138
# 2018-07-04  Wed  Jul  2018             134
# 2018-07-05  Thu  Jul  2018             145
# ...         ...  ...   ...             ...
# 2023-06-26  Mon  Jun  2023             194
# 2023-06-27  Tue  Jun  2023             192
# 2023-06-28  Wed  Jun  2023             172
# 2023-06-29  Thu  Jun  2023             250
# 2023-06-30  Fri  Jun  2023             305
#
# [1826 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1826 entries, 2018-07-01 to 2023-06-30
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Day             1826 non-null   object
#  1   Mont            1826 non-null   object
#  2   Year            1826 non-null   int64
#  3   transactions_6  1826 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 71.3+ KB

# %%
# df = df.loc[ :'2021-01-01']
# df

# %%
import seaborn as sns

# %%
# Understanding the data for time based train-test split
print(f'Start Date: {df.index.min()}')
print(f'End Date: {df.index.max()}')
print(f'Total Days: {len(df)}')
# Out:
# Start Date: 2018-07-01 00:00:00
# End Date: 2023-06-30 00:00:00
# Total Days: 1826

# %%
# Check for missing values in the entire DataFrame
missing_values = df.isnull().sum()

# Display the count of missing values for each column
print("Missing Values in Each Column:")
print(missing_values)
# Out:
# Missing Values in Each Column:
# Day               0
# Mont              0
# Year              0
# transactions_6    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)
plt.figure(figsize=(22, 6))
sns.lineplot(x=df.index, y=df['transactions_6'])
plt.title('The Variation # of visit from 06/2017 until 09/2017')
plt.show()

# %%
dm=df.reset_index()
dc=dm[['Date','transactions_6']].set_index(keys='Date')
dc
# Out:
#             transactions_6
# Date
# 2018-07-01               0
# 2018-07-02             156
# 2018-07-03             138
# 2018-07-04             134
# 2018-07-05             145
# ...                    ...
# 2023-06-26             194
# 2023-06-27             192
# 2023-06-28             172
# 2023-06-29             250
# 2023-06-30             305
#
# [1826 rows x 1 columns]

# %%
# i'm going to create a pivot table to plot the monthly temperatures through the years
dc['day'] = dc.index.day
dc['month'] = dc.index.month
pivot = pd.pivot_table(dc, values='transactions_6', index='month', columns='day', aggfunc='mean')
pivot.plot(figsize=(20,6))
plt.title('Monthly transactions_6 ')
plt.xlabel('Monthly')
plt.ylabel('transactions_6')
plt.xticks([x for x in range(1,13)])
plt.legend().remove()
plt.show()

# %%
monthly_seasonality = pivot.mean(axis=1)
monthly_seasonality.plot(figsize=(20,6))
plt.title('Monthly transactions_6 ')
plt.xlabel('Months')
plt.ylabel('transactions_6')
plt.xticks([x for x in range(1,13)])
plt.show()

# %%
year_avg = pd.pivot_table(dc, values='transactions_6', index='month', aggfunc='mean')
year_avg['03 Months MA'] = year_avg['transactions_6'].rolling(3).mean()
year_avg[['transactions_6','03 Months MA']].plot(figsize=(20,6))
plt.title('Monthly AVG transactions_6')
plt.xlabel('Months')
plt.ylabel('Temperature')
#plt.xticks([x for x in range(1900,2012,3)])
plt.show()

# %%
dc=df.reset_index()
dc=dm[['Date','transactions_6']].set_index(keys='Date')

# %%
dc.tail()
# Out:
#             transactions_6
# Date
# 2023-06-26             194
# 2023-06-27             192
# 2023-06-28             172
# 2023-06-29             250
# 2023-06-30             305

# %%
# Time based train-test splitting
valid = dc.loc['2023-03-31':]
train = dc.loc[:'2023-03-30']

print(f'Shape: Train={train.shape}, Validation={valid.shape}')

# Plotting the training and validation datasets
plt.figure(figsize=(12, 4))
plt.plot(train, label='Train')
plt.plot(valid, label='Validation')
plt.xlabel('Datetime')
plt.ylabel('Posts Published')
plt.title('Training and Validation Datasets')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Shape: Train=(1734, 1), Validation=(92, 1)

# %%
# Data Analysis
import pandas as pd
import numpy as np

# Data Visualization
from matplotlib import pyplot as plt
import seaborn as sns

# Statistics
import statsmodels.api as sm
from statsmodels.tsa.api import SimpleExpSmoothing, Holt, ExponentialSmoothing
from statsmodels.tsa.stattools import adfuller
from scipy.stats import boxcox
from scipy.special import inv_boxcox
from pmdarima import auto_arima
from prophet import Prophet

# Machine Learning
from sklearn.metrics import mean_squared_error

# Warnings
import warnings
warnings.filterwarnings('ignore')

# Loggers
import logging
logging.getLogger().setLevel(logging.ERROR)

# %%
# Visualizing the components of our time series: Trend, Seasonality, and Noise
decomposition = sm.tsa.seasonal_decompose(train)

# Plotting the components
fig, axes = plt.subplots(4, 1, figsize=(12, 10))
train.plot(title='Original', ax=axes[0])
decomposition.trend.plot(title='Trend', ax=axes[1])
decomposition.seasonal.plot(title='Seasonality', ax=axes[2])
decomposition.resid.plot(title='Residual', ax=axes[3])
plt.tight_layout()
plt.show()

# %%
# Creating a function to check stationarity of the given data
def check_stationarity(data):
    # Determining rolling statistics
    rol_mean = data.rolling(7).mean() #7 days in a week
    rol_std = data.rolling(7).std()
    
    # Plotting rolling statistics
    plt.figure(figsize=(12, 4))
    plt.plot(data, color='blue', label='Original')
    plt.plot(rol_mean, color='red', label='Rolling Mean')
    plt.plot(rol_std, color='black', label='Rolling Std')
    plt.xlabel('Datetime')
    plt.ylabel('Posts Published')
    plt.title('Rolling Mean and Standard Deviation')
    plt.legend()
    plt.tight_layout()
    plt.show()
    
    # Performing Dickey-Fuller test
    results = adfuller(data)
    df_output = pd.Series(results[:4], index=['Test Statistic', 'P-Value', '#Lags Used', 'Number of Observations Used'])
    for key, value in results[4].items():
        df_output[f'Critical Value ({key})'] = value
    print(f'Results of Dickey-Fuller Test:\n{df_output}')
    
# Stationarity check of our daily time series
check_stationarity(train)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -7.037292e+00
# P-Value                        5.970599e-10
# #Lags Used                     2.300000e+01
# Number of Observations Used    1.710000e+03
# Critical Value (1%)           -3.434180e+00
# Critical Value (5%)           -2.863232e+00
# Critical Value (10%)          -2.567671e+00
# dtype: float64

# %%
# First Differencing of boxcox-transformed time series
train_tfm_diff = train - train.shift(1)
train_tfm_diff.dropna(inplace=True)
check_stationarity(train_tfm_diff)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.554678e+01
# P-Value                        2.124952e-28
# #Lags Used                     2.000000e+01
# Number of Observations Used    1.712000e+03
# Critical Value (1%)           -3.434175e+00
# Critical Value (5%)           -2.863230e+00
# Critical Value (10%)          -2.567670e+00
# dtype: float64

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
plt.rcParams.update({'figure.figsize':(9,7), 'figure.dpi':120})



plot_acf(train.transactions_6)

# 1st Differencing

plot_acf(train.transactions_6)


plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_pacf(train,lags=40,title='daily bitcoin price')
plot_pacf(train.transactions_6,lags=40,title='daily bitcoin price')

# %%
# Auto-ARIMA on boxcox-transformed training time series without seasonality
auto_arima = auto_arima(train, d=0, seasonal=False)
print(auto_arima.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1734
# Model:               SARIMAX(2, 0, 2)   Log Likelihood               -9842.121
# Date:                Thu, 21 Dec 2023   AIC                          19696.243
# Time:                        20:25:40   BIC                          19728.992
# Sample:                    07-01-2018   HQIC                         19708.355
#                          - 03-30-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept    248.6639      5.972     41.639      0.000     236.959     260.368
# ar.L1         -0.4473      0.022    -19.989      0.000      -0.491      -0.403
# ar.L2         -0.8304      0.018    -46.981      0.000      -0.865      -0.796
# ma.L1          0.8044      0.021     37.730      0.000       0.763       0.846
# ma.L2          0.8058      0.020     40.722      0.000       0.767       0.845
# sigma2      4964.0465    194.779     25.486      0.000    4582.287    5345.806
# ===================================================================================
# Ljung-Box (L1) (Q):                  34.89   Jarque-Bera (JB):                13.38
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.21   Skew:                             0.20
# Prob(H) (two-sided):                  0.02   Kurtosis:                         2.83
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Residual Plots
auto_arima.plot_diagnostics(figsize=(12,8))
plt.tight_layout()
plt.show()

# %%
# Creating a function to plot the results of the forecast
def plot_forecast(forecast, model, rmse):
    plt.figure(figsize=(12,4))
    plt.plot(train, label='Training')
    plt.plot(valid, label='Actual')
    plt.plot(forecast, label='Forecast')
    plt.xlabel('Datetime')
    plt.ylabel('Posts Published')
    plt.title(f'{model} (RMSE: {round(rmse, 2)})')
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
resDiff = sm.tsa.arma_order_select_ic(train['transactions_6'], max_ar=7, max_ma=7, ic='aic', trend='c')
print('ARMA(p,q) =',resDiff['aic_min_order'],'is the best.')
# Out:
# ARMA(p,q) = (7, 7) is the best.

# %%
model = sm.tsa.statespace.SARIMAX(train, order=(7,0,7),dynamic=False, seasonal_order=(0,0,0,0), trend='c')
arima = model.fit(disp=0) 
print(arima.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:         transactions_6   No. Observations:                 1734
# Model:               SARIMAX(7, 0, 7)   Log Likelihood               -9119.352
# Date:                Thu, 21 Dec 2023   AIC                          18270.704
# Time:                        20:44:39   BIC                          18358.035
# Sample:                    07-01-2018   HQIC                         18303.002
#                          - 03-30-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     48.1883     14.196      3.394      0.001      20.364      76.012
# ar.L1         -0.0634      0.018     -3.459      0.001      -0.099      -0.027
# ar.L2         -0.0646      0.018     -3.569      0.000      -0.100      -0.029
# ar.L3         -0.0643      0.018     -3.480      0.001      -0.101      -0.028
# ar.L4         -0.0619      0.019     -3.326      0.001      -0.098      -0.025
# ar.L5         -0.0661      0.018     -3.630      0.000      -0.102      -0.030
# ar.L6         -0.0611      0.018     -3.333      0.001      -0.097      -0.025
# ar.L7          0.9277      0.018     51.450      0.000       0.892       0.963
# ma.L1          0.3110      0.025     12.673      0.000       0.263       0.359
# ma.L2          0.2352      0.028      8.536      0.000       0.181       0.289
# ma.L3          0.2408      0.030      7.903      0.000       0.181       0.300
# ma.L4          0.2171      0.032      6.878      0.000       0.155       0.279
# ma.L5          0.2099      0.030      7.027      0.000       0.151       0.268
# ma.L6          0.2142      0.030      7.235      0.000       0.156       0.272
# ma.L7         -0.6782      0.027    -24.830      0.000      -0.732      -0.625
# sigma2      2438.1602     60.799     40.102      0.000    2318.996    2557.324
# ===================================================================================
# Ljung-Box (L1) (Q):                  16.82   Jarque-Bera (JB):              1704.78
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.08   Skew:                            -0.90
# Prob(H) (two-sided):                  0.37   Kurtosis:                         7.51
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Residual Plots
arima.plot_diagnostics(figsize=(12,8))
plt.tight_layout()
plt.show()

# %%
forecast = arima.predict(0,(train.shape[0])-1).to_frame(name="forecast")
forecast
#forecast = inv_boxcox(forecast, lam)
forecast["date"]=train.index

forecast = forecast.set_index('date')
arima_rmse = mean_squared_error(train, forecast, squared=False)
plot_forecast(forecast, 'ARIMA Model', arima_rmse)

# %%
forecast = arima.predict(0,(valid.shape[0])-1, dynamic= False).to_frame(name="forecast")
forecast
#forecast = inv_boxcox(forecast, lam)
forecast["date"]=valid.index

forecast = forecast.set_index('date')
arima_rmse = mean_squared_error(valid, forecast, squared=False)
plot_forecast(forecast, 'ARIMA Model', arima_rmse)

# %%
forecast = arima.forecast(92).to_frame(name="forecast")
forecast
#forecast = inv_boxcox(forecast, lam)
forecast["date"]=valid.index

forecast = forecast.set_index('date')
arima_rmse = mean_squared_error(valid, forecast, squared=False)
plot_forecast(forecast, 'ARIMA Model', arima_rmse)

# %%
valid
# Out:
#             transactions_6
# Date
# 2023-03-31             270
# 2023-04-01               1
# 2023-04-02               0
# 2023-04-03             117
# 2023-04-04             132
# ...                    ...
# 2023-06-26             194
# 2023-06-27             192
# 2023-06-28             172
# 2023-06-29             250
# 2023-06-30             305
#
# [92 rows x 1 columns]

# %%
forecast['valid']=valid['transactions_6']
forecast['forecast']=forecast['forecast'].astype(int)
forecast['ecart']=forecast['forecast']-valid['transactions_6']

# %%
forecast['forecast']=forecast['forecast'].astype(int)

# %%
forecast['ecart']=forecast['forecast']-valid['transactions_6']

# %%
forecast
# Out:
#               forecast       ecart
# date
# 2023-03-31  178.159369  -91.840631
# 2023-04-01   19.783654   18.783654
# 2023-04-02   20.745402   20.745402
# 2023-04-03  160.402985   43.402985
# 2023-04-04  164.602790   32.602790
# ...                ...         ...
# 2023-06-26  142.510829  -51.489171
# 2023-06-27  147.494505  -44.505495
# 2023-06-28  124.634927  -47.365073
# 2023-06-29  152.612096  -97.387904
# 2023-06-30  153.621008 -151.378992
#
# [92 rows x 2 columns]

# %%
train.shape
# Out:
# (1734, 1)

# %%
# Generate predictions and with , dynamic=True
one_step_forecast = arima.get_prediction(start=-396) 

# Extract prediction mean
mean_forecast = one_step_forecast.predicted_mean

# Get confidence intervals of predictions
confidence_intervals = one_step_forecast.conf_int()
# Select lower and upper confidence limits
lower_limits = confidence_intervals.loc[:,'lower close']
upper_limits = confidence_intervals.loc[:,'upper close']

# %%
# Select lower and upper confidence limits
lower_limits = confidence_intervals.loc[:,'lower close']
upper_limits = confidence_intervals.loc[:,'upper close']

plt.plot(train.index, train, label='observed')

# plot your mean forecast
plt.plot(mean_forecast.index, mean_forecast, color='r', label='forecast')

# shade the area between your confidence limits
plt.fill_between(lower_limits.index, lower_limits, 
         upper_limits, color='pink')

# set labels, legends and show plot
plt.xlabel('Date')
plt.ylabel('Suger Price - Close USD')
plt.legend()
plt.show()

# %%
res = arima.resid
fig,ax = plt.subplots(2,1,figsize=(15,8))
fig = sm.graphics.tsa.plot_acf(res, lags=50, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(res, lags=50, ax=ax[1])
plt.show()

# %%
n_train=len(train)
n_train
# Out:
# 396

# %%
def walk_forward_validation(n_train, valid):
    # create dataframe to store the outcome
    result = pd.DataFrame(columns=['forecast', 'lower_interval', 'upper_interval'])
    # predict one point at a time
    for i in range(len(valid)):
        # define train set
        train_ = dc.iloc[:n_train+i, :].copy()
        
        # train the model
        arima = sm.tsa.statespace.SARIMAX(endog = train_, order=(4,1,3)).fit(method_kwargs={"warn_convergence": False})
        # get the forecast
        results = arima.get_prediction(60)
        
        # central
        result['forecast'] = results.predicted_mean
       
        # lower interval
        confidence_intervals = results.conf_int()
       # Select lower and upper confidence limits
        result['lower_interval'] = confidence_intervals.loc[:,'lower close']
        result['upper_interval'] = confidence_intervals.loc[:,'upper close']
        result = result.iloc[:29]
        
        print('result',result.shape)
    # join with test dataframe
    result.index=valid.index
    result = result.apply(pd.to_numeric)
    return valid.join(result)

result = walk_forward_validation(n_train, valid)
# Out:
# result (29, 3)
# result (29, 3)
# result (29, 3)
# result (29, 3)
# result (29, 3)
# result (29, 3)
# result (29, 3)
# result (29, 3)
# result (29, 3)
# result (29, 3)
# result (29, 3)
# result (29, 3)
# result (29, 3)
# result (29, 3)
# result (29, 3)
# result (29, 3)
# result (29, 3)
# result (29, 3)
# result (29, 3)
# result (29, 3)
# result (29, 3)
# result (29, 3)
# result (29, 3)
# result (29, 3)
# result (29, 3)
# result (29, 3)
# result (29, 3)
# result (29, 3)
# result (29, 3)

# %%
def walk_forward_validation1(train):
    # create dataframe to store the outcome
        result = pd.DataFrame(columns=['forecast', 'lower_interval', 'upper_interval'])
    # predict one point at a time
        # define train set
        #train_ = dc.iloc[:n_train+i, :].copy()
        
        # train the model
        arima = sm.tsa.statespace.SARIMAX(train, order=(4,1,3)).fit(method_kwargs={"warn_convergence": False})
        # get the forecast
        results = arima.get_prediction()
        
        # central
        result['forecast'] = results.predicted_mean
       
        # lower interval
        confidence_intervals = results.conf_int()
       # Select lower and upper confidence limits
        result['lower_interval'] = confidence_intervals.loc[:,'lower close']
        result['upper_interval'] = confidence_intervals.loc[:,'upper close']
        #result = result.iloc[:60]
        
        print('result',result.shape)
    # join with test dataframe
        #result.index=train.index
        result = result.apply(pd.to_numeric)
        return train.join(result)

result1 = walk_forward_validation1(train)
# Out:
# result (396, 3)

# %%
result.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
final = pd.concat([result1,result])

# %%
final.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
# Auto-ARIMA on boxcox-transformed training time series without seasonality
auto_arima = auto_arima(train, d=0, seasonal=True)
print(auto_arima.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1734
# Model:               SARIMAX(2, 0, 2)   Log Likelihood               -9842.121
# Date:                Mon, 25 Dec 2023   AIC                          19696.243
# Time:                        11:26:07   BIC                          19728.992
# Sample:                    07-01-2018   HQIC                         19708.355
#                          - 03-30-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept    248.6639      5.972     41.639      0.000     236.959     260.368
# ar.L1         -0.4473      0.022    -19.989      0.000      -0.491      -0.403
# ar.L2         -0.8304      0.018    -46.981      0.000      -0.865      -0.796
# ma.L1          0.8044      0.021     37.730      0.000       0.763       0.846
# ma.L2          0.8058      0.020     40.722      0.000       0.767       0.845
# sigma2      4964.0465    194.779     25.486      0.000    4582.287    5345.806
# ===================================================================================
# Ljung-Box (L1) (Q):                  34.89   Jarque-Bera (JB):                13.38
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.21   Skew:                             0.20
# Prob(H) (two-sided):                  0.02   Kurtosis:                         2.83
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
import itertools
import pandas as pd

# %%
p = d = q = range(0,3)

pdq= list(itertools.product(p , d , q))

pdqs = [(x[0],x[1],x[2],12) for x in list(itertools.product(p , d , q)) ]
ans=[]
for comb in pdq :
    for combs in pdqs :
        try:
            mod = sm.tsa.statespace.SARIMAX(train,
                                            order= comb,
                                            seasonal_order= combs,
                                            enforce_invertibility=False,
                                            enforce_stationarity=False)
            output = mod.fit()
            ans.append([comb,combs,output.aic])
            print("ARIMA {} + {}12': AIC Calculated ={}".format(comb,combs,output.aic))
        except:
            continue
ans_df = pd.DataFrame(ans,columns= ['pdq','pdqs','aic'])
#ans_df.loc[ans_df['aic'].min()]
# Out:
# ARIMA (0, 0, 0) + (0, 0, 0, 12)12': AIC Calculated =22005.656672794106
# ARIMA (0, 0, 0) + (0, 0, 1, 12)12': AIC Calculated =21574.919832726657
# ARIMA (0, 0, 0) + (0, 0, 2, 12)12': AIC Calculated =21309.490854128628
# ARIMA (0, 0, 0) + (0, 1, 0, 12)12': AIC Calculated =21849.665511811218
# ARIMA (0, 0, 0) + (0, 1, 1, 12)12': AIC Calculated =20095.46433238545
# ARIMA (0, 0, 0) + (0, 1, 2, 12)12': AIC Calculated =19669.025798975195
# ARIMA (0, 0, 0) + (0, 2, 0, 12)12': AIC Calculated =23651.841931009454
# ARIMA (0, 0, 0) + (0, 2, 1, 12)12': AIC Calculated =21606.261012902185
# ARIMA (0, 0, 0) + (0, 2, 2, 12)12': AIC Calculated =19922.19177814963
# ARIMA (0, 0, 0) + (1, 0, 0, 12)12': AIC Calculated =21369.130103872452
# ARIMA (0, 0, 0) + (1, 0, 1, 12)12': AIC Calculated =20238.452634702964
# ARIMA (0, 0, 0) + (1, 0, 2, 12)12': AIC Calculated =19814.370224922088
# ARIMA (0, 0, 0) + (1, 1, 0, 12)12': AIC Calculated =21054.28203078376
# ARIMA (0, 0, 0) + (1, 1, 1, 12)12': AIC Calculated =19915.989860115777
# ARIMA (0, 0, 0) + (1, 1, 2, 12)12': AIC Calculated =19670.537982295282
# ARIMA (0, 0, 0) + (1, 2, 0, 12)12': AIC Calculated =22499.979105681374
# ARIMA (0, 0, 0) + (1, 2, 1, 12)12': AIC Calculated =20965.30638059781
# ARIMA (0, 0, 0) + (1, 2, 2, 12)12': AIC Calculated =19750.85926725186
# ARIMA (0, 0, 0) + (2, 0, 0, 12)12': AIC Calculated =20891.675431307503
# ARIMA (0, 0, 0) + (2, 0, 1, 12)12': AIC Calculated =19916.771263650953
# ARIMA (0, 0, 0) + (2, 0, 2, 12)12': AIC Calculated =19884.90076443717
# ARIMA (0, 0, 0) + (2, 1, 0, 12)12': AIC Calculated =20338.823992296362
# ARIMA (0, 0, 0) + (2, 1, 1, 12)12': AIC Calculated =19630.014393766523
# ARIMA (0, 0, 0) + (2, 1, 2, 12)12': AIC Calculated =19620.493348377997
# ARIMA (0, 0, 0) + (2, 2, 0, 12)12': AIC Calculated =21622.983072142677
# ARIMA (0, 0, 0) + (2, 2, 1, 12)12': AIC Calculated =20266.58189733951
# ARIMA (0, 0, 0) + (2, 2, 2, 12)12': AIC Calculated =19606.774478483392
# ARIMA (0, 0, 1) + (0, 0, 0, 12)12': AIC Calculated =20917.71278190666
# ARIMA (0, 0, 1) + (0, 0, 1, 12)12': AIC Calculated =20704.977605699198
# ARIMA (0, 0, 1) + (0, 0, 2, 12)12': AIC Calculated =20443.83389198289
# ARIMA (0, 0, 1) + (0, 1, 0, 12)12': AIC Calculated =21457.784737010756
# ARIMA (0, 0, 1) + (0, 1, 1, 12)12': AIC Calculated =19780.384338530996
# ARIMA (0, 0, 1) + (0, 1, 2, 12)12': AIC Calculated =19427.466677699733
# ARIMA (0, 0, 1) + (0, 2, 0, 12)12': AIC Calculated =23281.879090768787
# ARIMA (0, 0, 1) + (0, 2, 1, 12)12': AIC Calculated =21221.208138738333
# ARIMA (0, 0, 1) + (0, 2, 2, 12)12': AIC Calculated =19619.215179218707
# ARIMA (0, 0, 1) + (1, 0, 0, 12)12': AIC Calculated =20683.248619113234
# ARIMA (0, 0, 1) + (1, 0, 1, 12)12': AIC Calculated =19925.882257692523
# ARIMA (0, 0, 1) + (1, 0, 2, 12)12': AIC Calculated =19583.850026177628
# ARIMA (0, 0, 1) + (1, 1, 0, 12)12': AIC Calculated =20588.995148891114
# ARIMA (0, 0, 1) + (1, 1, 1, 12)12': AIC Calculated =19617.895691726277
# ARIMA (0, 0, 1) + (1, 1, 2, 12)12': AIC Calculated =19427.256337795166
# ARIMA (0, 0, 1) + (1, 2, 0, 12)12': AIC Calculated =21910.189163870848
# ARIMA (0, 0, 1) + (1, 2, 1, 12)12': AIC Calculated =20492.371654496776
# ARIMA (0, 0, 1) + (1, 2, 2, 12)12': AIC Calculated =19462.465682231712
# ARIMA (0, 0, 1) + (2, 0, 0, 12)12': AIC Calculated =20327.299453598596
# ARIMA (0, 0, 1) + (2, 0, 1, 12)12': AIC Calculated =19635.536259860448
# ARIMA (0, 0, 1) + (2, 0, 2, 12)12': AIC Calculated =19586.707639214557
# ARIMA (0, 0, 1) + (2, 1, 0, 12)12': AIC Calculated =20120.317686746144
# ARIMA (0, 0, 1) + (2, 1, 1, 12)12': AIC Calculated =19458.462276520186
# ARIMA (0, 0, 1) + (2, 1, 2, 12)12': AIC Calculated =19366.141391138015
# ARIMA (0, 0, 1) + (2, 2, 0, 12)12': AIC Calculated =21168.923619397407
# ARIMA (0, 0, 1) + (2, 2, 1, 12)12': AIC Calculated =20049.751666475284
# ARIMA (0, 0, 1) + (2, 2, 2, 12)12': AIC Calculated =19428.289423638926
# ARIMA (0, 0, 2) + (0, 0, 0, 12)12': AIC Calculated =20793.623731129297
# ARIMA (0, 0, 2) + (0, 0, 1, 12)12': AIC Calculated =20643.326896927283
# ARIMA (0, 0, 2) + (0, 0, 2, 12)12': AIC Calculated =20347.232955895244
# ARIMA (0, 0, 2) + (0, 1, 0, 12)12': AIC Calculated =21226.19516985774
# ARIMA (0, 0, 2) + (0, 1, 1, 12)12': AIC Calculated =19684.19572849464
# ARIMA (0, 0, 2) + (0, 1, 2, 12)12': AIC Calculated =19409.051253436373
# ARIMA (0, 0, 2) + (0, 2, 0, 12)12': AIC Calculated =22856.873375489067
# ARIMA (0, 0, 2) + (0, 2, 1, 12)12': AIC Calculated =20992.946093611878
# ARIMA (0, 0, 2) + (0, 2, 2, 12)12': AIC Calculated =19522.35774862273
# ARIMA (0, 0, 2) + (1, 0, 0, 12)12': AIC Calculated =20667.03728739004
# ARIMA (0, 0, 2) + (1, 0, 1, 12)12': AIC Calculated =19825.172761092173
# ARIMA (0, 0, 2) + (1, 0, 2, 12)12': AIC Calculated =19649.58477992472
# ARIMA (0, 0, 2) + (1, 1, 0, 12)12': AIC Calculated =20577.93686873641
# ARIMA (0, 0, 2) + (1, 1, 1, 12)12': AIC Calculated =19593.848756906023
# ARIMA (0, 0, 2) + (1, 1, 2, 12)12': AIC Calculated =19401.993375049835
# ARIMA (0, 0, 2) + (1, 2, 0, 12)12': AIC Calculated =21900.678409373082
# ARIMA (0, 0, 2) + (1, 2, 1, 12)12': AIC Calculated =20469.399831271985
# ARIMA (0, 0, 2) + (1, 2, 2, 12)12': AIC Calculated =19437.361915489815
# ARIMA (0, 0, 2) + (2, 0, 0, 12)12': AIC Calculated =20322.615623164464
# ARIMA (0, 0, 2) + (2, 0, 1, 12)12': AIC Calculated =19651.44731079753
# ARIMA (0, 0, 2) + (2, 0, 2, 12)12': AIC Calculated =20226.15518903658
# ARIMA (0, 0, 2) + (2, 1, 0, 12)12': AIC Calculated =20070.142942817234
# ARIMA (0, 0, 2) + (2, 1, 1, 12)12': AIC Calculated =19433.8956246154
# ARIMA (0, 0, 2) + (2, 1, 2, 12)12': AIC Calculated =19355.917853137456
# ARIMA (0, 0, 2) + (2, 2, 0, 12)12': AIC Calculated =21158.349251240295
# ARIMA (0, 0, 2) + (2, 2, 1, 12)12': AIC Calculated =19999.31725386155
# ARIMA (0, 0, 2) + (2, 2, 2, 12)12': AIC Calculated =19426.07775816803
# ARIMA (0, 1, 0) + (0, 0, 0, 12)12': AIC Calculated =20972.427286512695
# ARIMA (0, 1, 0) + (0, 0, 1, 12)12': AIC Calculated =20411.886476034502
# ARIMA (0, 1, 0) + (0, 0, 2, 12)12': AIC Calculated =20276.42986379251
# ARIMA (0, 1, 0) + (0, 1, 0, 12)12': AIC Calculated =22660.209998985214
# ARIMA (0, 1, 0) + (0, 1, 1, 12)12': AIC Calculated =20745.671001118862
# ARIMA (0, 1, 0) + (0, 1, 2, 12)12': AIC Calculated =20189.05477931257
# ARIMA (0, 1, 0) + (0, 2, 0, 12)12': AIC Calculated =24587.340309378833
# ARIMA (0, 1, 0) + (0, 2, 1, 12)12': AIC Calculated =22405.43900663698
# ARIMA (0, 1, 0) + (0, 2, 2, 12)12': AIC Calculated =20561.759014434523
# ARIMA (0, 1, 0) + (1, 0, 0, 12)12': AIC Calculated =20456.185738244192
# ARIMA (0, 1, 0) + (1, 0, 1, 12)12': AIC Calculated =20409.245025683114
# ARIMA (0, 1, 0) + (1, 0, 2, 12)12': AIC Calculated =20269.130415720647
# ARIMA (0, 1, 0) + (1, 1, 0, 12)12': AIC Calculated =21409.915822257197
# ARIMA (0, 1, 0) + (1, 1, 1, 12)12': AIC Calculated =20368.674270121952
# ARIMA (0, 1, 0) + (1, 1, 2, 12)12': AIC Calculated =20184.619215477604
# ARIMA (0, 1, 0) + (1, 2, 0, 12)12': AIC Calculated =22860.16954536959
# ARIMA (0, 1, 0) + (1, 2, 1, 12)12': AIC Calculated =21318.5279319166
# ARIMA (0, 1, 0) + (1, 2, 2, 12)12': AIC Calculated =20213.158838605712
# ARIMA (0, 1, 0) + (2, 0, 0, 12)12': AIC Calculated =20294.62621075305
# ARIMA (0, 1, 0) + (2, 0, 1, 12)12': AIC Calculated =20169.20504550098
# ARIMA (0, 1, 0) + (2, 0, 2, 12)12': AIC Calculated =19704.943425666235
# ARIMA (0, 1, 0) + (2, 1, 0, 12)12': AIC Calculated =20882.026038250468
# ARIMA (0, 1, 0) + (2, 1, 1, 12)12': AIC Calculated =20206.342624851626
# ARIMA (0, 1, 0) + (2, 1, 2, 12)12': AIC Calculated =20065.530290018953
# ARIMA (0, 1, 0) + (2, 2, 0, 12)12': AIC Calculated =21936.950495241632
# ARIMA (0, 1, 0) + (2, 2, 1, 12)12': AIC Calculated =20805.6188591595
# ARIMA (0, 1, 0) + (2, 2, 2, 12)12': AIC Calculated =20770.63852609028
# ARIMA (0, 1, 1) + (0, 0, 0, 12)12': AIC Calculated =20290.14196023144
# ARIMA (0, 1, 1) + (0, 0, 1, 12)12': AIC Calculated =19765.750916935678
# ARIMA (0, 1, 1) + (0, 0, 2, 12)12': AIC Calculated =19631.53627604888
# ARIMA (0, 1, 1) + (0, 1, 0, 12)12': AIC Calculated =21833.60421250553
# ARIMA (0, 1, 1) + (0, 1, 1, 12)12': AIC Calculated =20072.653892814
# ARIMA (0, 1, 1) + (0, 1, 2, 12)12': AIC Calculated =19555.260789697608
# ARIMA (0, 1, 1) + (0, 2, 0, 12)12': AIC Calculated =23633.267788600373
# ARIMA (0, 1, 1) + (0, 2, 1, 12)12': AIC Calculated =21595.64527142018
# ARIMA (0, 1, 1) + (0, 2, 2, 12)12': AIC Calculated =19906.912692928003
# ARIMA (0, 1, 1) + (1, 0, 0, 12)12': AIC Calculated =19960.528561930918
# ARIMA (0, 1, 1) + (1, 0, 1, 12)12': AIC Calculated =19767.237191127373
# ARIMA (0, 1, 1) + (1, 0, 2, 12)12': AIC Calculated =19550.072957651042
# ARIMA (0, 1, 1) + (1, 1, 0, 12)12': AIC Calculated =21051.998805506442
# ARIMA (0, 1, 1) + (1, 1, 1, 12)12': AIC Calculated =19868.210309867896
# ARIMA (0, 1, 1) + (1, 1, 2, 12)12': AIC Calculated =19556.88454825557
# ARIMA (0, 1, 1) + (1, 2, 0, 12)12': AIC Calculated =22496.880702335093
# ARIMA (0, 1, 1) + (1, 2, 1, 12)12': AIC Calculated =20956.668201850844
# ARIMA (0, 1, 1) + (1, 2, 2, 12)12': AIC Calculated =19987.812549383394
# ARIMA (0, 1, 1) + (2, 0, 0, 12)12': AIC Calculated =19605.84308351753
# ARIMA (0, 1, 1) + (2, 0, 1, 12)12': AIC Calculated =19596.704356328853
# ARIMA (0, 1, 1) + (2, 0, 2, 12)12': AIC Calculated =19530.46717514556
# ARIMA (0, 1, 1) + (2, 1, 0, 12)12': AIC Calculated =20336.85877193825
# ARIMA (0, 1, 1) + (2, 1, 1, 12)12': AIC Calculated =19531.20428564561
# ARIMA (0, 1, 1) + (2, 1, 2, 12)12': AIC Calculated =19557.58768206087
# ARIMA (0, 1, 1) + (2, 2, 0, 12)12': AIC Calculated =21931.749863477242
# ARIMA (0, 1, 1) + (2, 2, 1, 12)12': AIC Calculated =20271.40745233095
# ARIMA (0, 1, 1) + (2, 2, 2, 12)12': AIC Calculated =19515.99273876757
# ARIMA (0, 1, 2) + (0, 0, 0, 12)12': AIC Calculated =19978.837112067173
# ARIMA (0, 1, 2) + (0, 0, 1, 12)12': AIC Calculated =19589.26692572212
# ARIMA (0, 1, 2) + (0, 0, 2, 12)12': AIC Calculated =19453.279798227097
# ARIMA (0, 1, 2) + (0, 1, 0, 12)12': AIC Calculated =21442.39272818933
# ARIMA (0, 1, 2) + (0, 1, 1, 12)12': AIC Calculated =19761.774351388587
# ARIMA (0, 1, 2) + (0, 1, 2, 12)12': AIC Calculated =19385.594750906977
# ARIMA (0, 1, 2) + (0, 2, 0, 12)12': AIC Calculated =23261.847807902795
# ARIMA (0, 1, 2) + (0, 2, 1, 12)12': AIC Calculated =21207.737035720093
# ARIMA (0, 1, 2) + (0, 2, 2, 12)12': AIC Calculated =19995.90705310375
# ARIMA (0, 1, 2) + (1, 0, 0, 12)12': AIC Calculated =19696.101862025465
# ARIMA (0, 1, 2) + (1, 0, 1, 12)12': AIC Calculated =19587.002169373976
# ARIMA (0, 1, 2) + (1, 0, 2, 12)12': AIC Calculated =19396.987668907685
# ARIMA (0, 1, 2) + (1, 1, 0, 12)12': AIC Calculated =20586.32997255758
# ARIMA (0, 1, 2) + (1, 1, 1, 12)12': AIC Calculated =19590.47357969585
# ARIMA (0, 1, 2) + (1, 1, 2, 12)12': AIC Calculated =19384.77762838523
# ARIMA (0, 1, 2) + (1, 2, 0, 12)12': AIC Calculated =21906.588713083012
# ARIMA (0, 1, 2) + (1, 2, 1, 12)12': AIC Calculated =20481.920495177954
# ARIMA (0, 1, 2) + (1, 2, 2, 12)12': AIC Calculated =20229.315385771017
# ARIMA (0, 1, 2) + (2, 0, 0, 12)12': AIC Calculated =19506.2745190997
# ARIMA (0, 1, 2) + (2, 0, 1, 12)12': AIC Calculated =19492.373867977116
# ARIMA (0, 1, 2) + (2, 0, 2, 12)12': AIC Calculated =19393.163931163435
# ARIMA (0, 1, 2) + (2, 1, 0, 12)12': AIC Calculated =20117.46910554941
# ARIMA (0, 1, 2) + (2, 1, 1, 12)12': AIC Calculated =19432.174883915588
# ARIMA (0, 1, 2) + (2, 1, 2, 12)12': AIC Calculated =19336.434105305598
# ARIMA (0, 1, 2) + (2, 2, 0, 12)12': AIC Calculated =21164.95496822869
# ARIMA (0, 1, 2) + (2, 2, 1, 12)12': AIC Calculated =21378.35991290112
# ARIMA (0, 1, 2) + (2, 2, 2, 12)12': AIC Calculated =19837.030896259206
# ARIMA (0, 2, 0) + (0, 0, 0, 12)12': AIC Calculated =22390.538457758477
# ARIMA (0, 2, 0) + (0, 0, 1, 12)12': AIC Calculated =21930.666738449247
# ARIMA (0, 2, 0) + (0, 0, 2, 12)12': AIC Calculated =21786.029624778654
# ARIMA (0, 2, 0) + (0, 1, 0, 12)12': AIC Calculated =24041.35579826623
# ARIMA (0, 2, 0) + (0, 1, 1, 12)12': AIC Calculated =22143.484797936977
# ARIMA (0, 2, 0) + (0, 1, 2, 12)12': AIC Calculated =21685.534183050862
# ARIMA (0, 2, 0) + (0, 2, 0, 12)12': AIC Calculated =25993.992233567682
# ARIMA (0, 2, 0) + (0, 2, 1, 12)12': AIC Calculated =23765.824216686677
# ARIMA (0, 2, 0) + (0, 2, 2, 12)12': AIC Calculated =21941.856388529144
# ARIMA (0, 2, 0) + (1, 0, 0, 12)12': AIC Calculated =21905.274676124736
# ARIMA (0, 2, 0) + (1, 0, 1, 12)12': AIC Calculated =21891.007138392553
# ARIMA (0, 2, 0) + (1, 0, 2, 12)12': AIC Calculated =21741.65497013078
# ARIMA (0, 2, 0) + (1, 1, 0, 12)12': AIC Calculated =22604.636798237254
# ARIMA (0, 2, 0) + (1, 1, 1, 12)12': AIC Calculated =21805.5984775088
# ARIMA (0, 2, 0) + (1, 1, 2, 12)12': AIC Calculated =21638.232767352412
# ARIMA (0, 2, 0) + (1, 2, 0, 12)12': AIC Calculated =23963.619454697542
# ARIMA (0, 2, 0) + (1, 2, 1, 12)12': AIC Calculated =22502.53088872564
# ARIMA (0, 2, 0) + (1, 2, 2, 12)12': AIC Calculated =21641.07534611824
# ARIMA (0, 2, 0) + (2, 0, 0, 12)12': AIC Calculated =21754.088504844836
# ARIMA (0, 2, 0) + (2, 0, 1, 12)12': AIC Calculated =21754.974717321016
# ARIMA (0, 2, 0) + (2, 0, 2, 12)12': AIC Calculated =21171.379453459143
# ARIMA (0, 2, 0) + (2, 1, 0, 12)12': AIC Calculated =22224.2576525351
# ARIMA (0, 2, 0) + (2, 1, 1, 12)12': AIC Calculated =22019.297264687902
# ARIMA (0, 2, 0) + (2, 1, 2, 12)12': AIC Calculated =21534.695151230804
# ARIMA (0, 2, 0) + (2, 2, 0, 12)12': AIC Calculated =22983.060031707813
# ARIMA (0, 2, 0) + (2, 2, 1, 12)12': AIC Calculated =22137.951325237682
# ARIMA (0, 2, 0) + (2, 2, 2, 12)12': AIC Calculated =21911.217635385627
# ARIMA (0, 2, 1) + (0, 0, 0, 12)12': AIC Calculated =20959.09464296244
# ARIMA (0, 2, 1) + (0, 0, 1, 12)12': AIC Calculated =20397.551653660325
# ARIMA (0, 2, 1) + (0, 0, 2, 12)12': AIC Calculated =20260.674446157223
# ARIMA (0, 2, 1) + (0, 1, 0, 12)12': AIC Calculated =22643.186319256834
# ARIMA (0, 2, 1) + (0, 1, 1, 12)12': AIC Calculated =20732.52353560836
# ARIMA (0, 2, 1) + (0, 1, 2, 12)12': AIC Calculated =20181.987784117468
# ARIMA (0, 2, 1) + (0, 2, 0, 12)12': AIC Calculated =24566.016005701407
# ARIMA (0, 2, 1) + (0, 2, 1, 12)12': AIC Calculated =22392.02575183709
# ARIMA (0, 2, 1) + (0, 2, 2, 12)12': AIC Calculated =20554.518370674574
# ARIMA (0, 2, 1) + (1, 0, 0, 12)12': AIC Calculated =20454.504564199466
# ARIMA (0, 2, 1) + (1, 0, 1, 12)12': AIC Calculated =20394.66543696851
# ARIMA (0, 2, 1) + (1, 0, 2, 12)12': AIC Calculated =20254.394172619817
# ARIMA (0, 2, 1) + (1, 1, 0, 12)12': AIC Calculated =21407.658086196996
# ARIMA (0, 2, 1) + (1, 1, 1, 12)12': AIC Calculated =20357.716578719137
# ARIMA (0, 2, 1) + (1, 1, 2, 12)12': AIC Calculated =20177.261169234545
# ARIMA (0, 2, 1) + (1, 2, 0, 12)12': AIC Calculated =22856.958517182145
# ARIMA (0, 2, 1) + (1, 2, 1, 12)12': AIC Calculated =21308.47483774794
# ARIMA (0, 2, 1) + (1, 2, 2, 12)12': AIC Calculated =20209.72470537942
# ARIMA (0, 2, 1) + (2, 0, 0, 12)12': AIC Calculated =20292.179614026678
# ARIMA (0, 2, 1) + (2, 0, 1, 12)12': AIC Calculated =20278.120787753258
# ARIMA (0, 2, 1) + (2, 0, 2, 12)12': AIC Calculated =20251.3791890027
# ARIMA (0, 2, 1) + (2, 1, 0, 12)12': AIC Calculated =20879.216791156658
# ARIMA (0, 2, 1) + (2, 1, 1, 12)12': AIC Calculated =20866.555803214884
# ARIMA (0, 2, 1) + (2, 1, 2, 12)12': AIC Calculated =20793.690375148566
# ARIMA (0, 2, 1) + (2, 2, 0, 12)12': AIC Calculated =21933.769695826057
# ARIMA (0, 2, 1) + (2, 2, 1, 12)12': AIC Calculated =20810.12354511281
# ARIMA (0, 2, 1) + (2, 2, 2, 12)12': AIC Calculated =20761.243192930706
# ARIMA (0, 2, 2) + (0, 0, 0, 12)12': AIC Calculated =20719.167588992634
# ARIMA (0, 2, 2) + (0, 0, 1, 12)12': AIC Calculated =20422.490493461526
# ARIMA (0, 2, 2) + (0, 0, 2, 12)12': AIC Calculated =20282.451356949357
# ARIMA (0, 2, 2) + (0, 1, 0, 12)12': AIC Calculated =22499.70870943035
# ARIMA (0, 2, 2) + (0, 1, 1, 12)12': AIC Calculated =20299.19766098709
# ARIMA (0, 2, 2) + (0, 1, 2, 12)12': AIC Calculated =20508.64848140547
# ARIMA (0, 2, 2) + (0, 2, 0, 12)12': AIC Calculated =24890.620311480056
# ARIMA (0, 2, 2) + (0, 2, 1, 12)12': AIC Calculated =22482.059700187558
# ARIMA (0, 2, 2) + (0, 2, 2, 12)12': AIC Calculated =22857.8950635243
# ARIMA (0, 2, 2) + (1, 0, 0, 12)12': AIC Calculated =20521.99113376325
# ARIMA (0, 2, 2) + (1, 0, 1, 12)12': AIC Calculated =20423.609741429453
# ARIMA (0, 2, 2) + (1, 0, 2, 12)12': AIC Calculated =20245.851775979347
# ARIMA (0, 2, 2) + (1, 1, 0, 12)12': AIC Calculated =21059.916040902193
# ARIMA (0, 2, 2) + (1, 1, 1, 12)12': AIC Calculated =19946.752013480578
# ARIMA (0, 2, 2) + (1, 1, 2, 12)12': AIC Calculated =21792.46765879412
# ARIMA (0, 2, 2) + (1, 2, 0, 12)12': AIC Calculated =22502.847240230272
# ARIMA (0, 2, 2) + (1, 2, 1, 12)12': AIC Calculated =21306.51980017637
# ARIMA (0, 2, 2) + (1, 2, 2, 12)12': AIC Calculated =21689.776771302386
# ARIMA (0, 2, 2) + (2, 0, 0, 12)12': AIC Calculated =20298.383951814278
# ARIMA (0, 2, 2) + (2, 0, 1, 12)12': AIC Calculated =20294.30116277597
# ARIMA (0, 2, 2) + (2, 0, 2, 12)12': AIC Calculated =20259.308738645017
# ARIMA (0, 2, 2) + (2, 1, 0, 12)12': AIC Calculated =21922.97604986232
# ARIMA (0, 2, 2) + (2, 1, 1, 12)12': AIC Calculated =20831.935649054838
# ARIMA (0, 2, 2) + (2, 1, 2, 12)12': AIC Calculated =21759.151969171362
# ARIMA (0, 2, 2) + (2, 2, 0, 12)12': AIC Calculated =21928.374189653798
# ARIMA (0, 2, 2) + (2, 2, 1, 12)12': AIC Calculated =20349.983929874084
# ARIMA (0, 2, 2) + (2, 2, 2, 12)12': AIC Calculated =20741.52045647588
# ARIMA (1, 0, 0) + (0, 0, 0, 12)12': AIC Calculated =20730.154138843525
# ARIMA (1, 0, 0) + (0, 0, 1, 12)12': AIC Calculated =20351.382749877084
# ARIMA (1, 0, 0) + (0, 0, 2, 12)12': AIC Calculated =20201.740768216478
# ARIMA (1, 0, 0) + (0, 1, 0, 12)12': AIC Calculated =21786.757803426648
# ARIMA (1, 0, 0) + (0, 1, 1, 12)12': AIC Calculated =19974.436450547255
# ARIMA (1, 0, 0) + (0, 1, 2, 12)12': AIC Calculated =19499.090234881907
# ARIMA (1, 0, 0) + (0, 2, 0, 12)12': AIC Calculated =23625.607215572512
# ARIMA (1, 0, 0) + (0, 2, 1, 12)12': AIC Calculated =21544.08136860645
# ARIMA (1, 0, 0) + (0, 2, 2, 12)12': AIC Calculated =19807.390766179917
# ARIMA (1, 0, 0) + (1, 0, 0, 12)12': AIC Calculated =20336.63899621176
# ARIMA (1, 0, 0) + (1, 0, 1, 12)12': AIC Calculated =20332.01227576782
# ARIMA (1, 0, 0) + (1, 0, 2, 12)12': AIC Calculated =20196.715442034576
# ARIMA (1, 0, 0) + (1, 1, 0, 12)12': AIC Calculated =20788.767855405007
# ARIMA (1, 0, 0) + (1, 1, 1, 12)12': AIC Calculated =19713.004155989445
# ARIMA (1, 0, 0) + (1, 1, 2, 12)12': AIC Calculated =19500.506947074013
# ARIMA (1, 0, 0) + (1, 2, 0, 12)12': AIC Calculated =22240.098667795304
# ARIMA (1, 0, 0) + (1, 2, 1, 12)12': AIC Calculated =20714.719221851454
# ARIMA (1, 0, 0) + (1, 2, 2, 12)12': AIC Calculated =19556.670210895056
# ARIMA (1, 0, 0) + (2, 0, 0, 12)12': AIC Calculated =20193.91209079068
# ARIMA (1, 0, 0) + (2, 0, 1, 12)12': AIC Calculated =19706.321611701984
# ARIMA (1, 0, 0) + (2, 0, 2, 12)12': AIC Calculated =19812.616075094506
# ARIMA (1, 0, 0) + (2, 1, 0, 12)12': AIC Calculated =20198.073785902572
# ARIMA (1, 0, 0) + (2, 1, 1, 12)12': AIC Calculated =19499.7857261916
# ARIMA (1, 0, 0) + (2, 1, 2, 12)12': AIC Calculated =19422.371597416182
# ARIMA (1, 0, 0) + (2, 2, 0, 12)12': AIC Calculated =21369.167547193072
# ARIMA (1, 0, 0) + (2, 2, 1, 12)12': AIC Calculated =20125.56033400431
# ARIMA (1, 0, 0) + (2, 2, 2, 12)12': AIC Calculated =19502.677213934345
# ARIMA (1, 0, 1) + (0, 0, 0, 12)12': AIC Calculated =20350.685029676457
# ARIMA (1, 0, 1) + (0, 0, 1, 12)12': AIC Calculated =19779.070408795575
# ARIMA (1, 0, 1) + (0, 0, 2, 12)12': AIC Calculated =19644.96447232327
# ARIMA (1, 0, 1) + (0, 1, 0, 12)12': AIC Calculated =21345.297607015716
# ARIMA (1, 0, 1) + (0, 1, 1, 12)12': AIC Calculated =20082.581258849255
# ARIMA (1, 0, 1) + (0, 1, 2, 12)12': AIC Calculated =19418.459287706886
# ARIMA (1, 0, 1) + (0, 2, 0, 12)12': AIC Calculated =23064.28889707133
# ARIMA (1, 0, 1) + (0, 2, 1, 12)12': AIC Calculated =21522.642599767234
# ARIMA (1, 0, 1) + (0, 2, 2, 12)12': AIC Calculated =19913.636504579852
# ARIMA (1, 0, 1) + (1, 0, 0, 12)12': AIC Calculated =19963.002808536654
# ARIMA (1, 0, 1) + (1, 0, 1, 12)12': AIC Calculated =19787.937863787603
# ARIMA (1, 0, 1) + (1, 0, 2, 12)12': AIC Calculated =19654.624007943363
# ARIMA (1, 0, 1) + (1, 1, 0, 12)12': AIC Calculated =20573.00386109422
# ARIMA (1, 0, 1) + (1, 1, 1, 12)12': AIC Calculated =19865.495121150547
# ARIMA (1, 0, 1) + (1, 1, 2, 12)12': AIC Calculated =19412.511297749646
# ARIMA (1, 0, 1) + (1, 2, 0, 12)12': AIC Calculated =21895.534861895023
# ARIMA (1, 0, 1) + (1, 2, 1, 12)12': AIC Calculated =20930.578881715162
# ARIMA (1, 0, 1) + (1, 2, 2, 12)12': AIC Calculated =19735.779356031722
# ARIMA (1, 0, 1) + (2, 0, 0, 12)12': AIC Calculated =19607.88279910849
# ARIMA (1, 0, 1) + (2, 0, 1, 12)12': AIC Calculated =19759.710197988257
# ARIMA (1, 0, 1) + (2, 0, 2, 12)12': AIC Calculated =19770.10475505582
# ARIMA (1, 0, 1) + (2, 1, 0, 12)12': AIC Calculated =20075.701845600266
# ARIMA (1, 0, 1) + (2, 1, 1, 12)12': AIC Calculated =19418.88047020859
# ARIMA (1, 0, 1) + (2, 1, 2, 12)12': AIC Calculated =19408.07377064706
# ARIMA (1, 0, 1) + (2, 2, 0, 12)12': AIC Calculated =21154.333947268013
# ARIMA (1, 0, 1) + (2, 2, 1, 12)12': AIC Calculated =20003.911646651206
# ARIMA (1, 0, 1) + (2, 2, 2, 12)12': AIC Calculated =19507.528609278645
# ARIMA (1, 0, 2) + (0, 0, 0, 12)12': AIC Calculated =20040.05814740264
# ARIMA (1, 0, 2) + (0, 0, 1, 12)12': AIC Calculated =19710.945363792125
# ARIMA (1, 0, 2) + (0, 0, 2, 12)12': AIC Calculated =19575.4084097348
# ARIMA (1, 0, 2) + (0, 1, 0, 12)12': AIC Calculated =21201.751186206486
# ARIMA (1, 0, 2) + (0, 1, 1, 12)12': AIC Calculated =19667.736359190465
# ARIMA (1, 0, 2) + (0, 1, 2, 12)12': AIC Calculated =19391.495319833157
# ARIMA (1, 0, 2) + (0, 2, 0, 12)12': AIC Calculated =22856.784572367906
# ARIMA (1, 0, 2) + (0, 2, 1, 12)12': AIC Calculated =20968.728097059808
# ARIMA (1, 0, 2) + (0, 2, 2, 12)12': AIC Calculated =19505.42219866882
# ARIMA (1, 0, 2) + (1, 0, 0, 12)12': AIC Calculated =19782.697269451914
# ARIMA (1, 0, 2) + (1, 0, 1, 12)12': AIC Calculated =19710.219919235205
# ARIMA (1, 0, 2) + (1, 0, 2, 12)12': AIC Calculated =19583.169921789817
# ARIMA (1, 0, 2) + (1, 1, 0, 12)12': AIC Calculated =20513.491888635108
# ARIMA (1, 0, 2) + (1, 1, 1, 12)12': AIC Calculated =19580.22170584869
# ARIMA (1, 0, 2) + (1, 1, 2, 12)12': AIC Calculated =19474.600323018894
# ARIMA (1, 0, 2) + (1, 2, 0, 12)12': AIC Calculated =21770.621810599547
# ARIMA (1, 0, 2) + (1, 2, 1, 12)12': AIC Calculated =20427.22795536428
# ARIMA (1, 0, 2) + (1, 2, 2, 12)12': AIC Calculated =19456.866068158743
# ARIMA (1, 0, 2) + (2, 0, 0, 12)12': AIC Calculated =19607.88515115332
# ARIMA (1, 0, 2) + (2, 0, 1, 12)12': AIC Calculated =19616.760457834014
# ARIMA (1, 0, 2) + (2, 0, 2, 12)12': AIC Calculated =19578.517962094036
# ARIMA (1, 0, 2) + (2, 1, 0, 12)12': AIC Calculated =20051.40656069605
# ARIMA (1, 0, 2) + (2, 1, 1, 12)12': AIC Calculated =19418.760949281535
# ARIMA (1, 0, 2) + (2, 1, 2, 12)12': AIC Calculated =19344.732928302987
# ARIMA (1, 0, 2) + (2, 2, 0, 12)12': AIC Calculated =21059.392783583746
# ARIMA (1, 0, 2) + (2, 2, 1, 12)12': AIC Calculated =19981.480987374598
# ARIMA (1, 0, 2) + (2, 2, 2, 12)12': AIC Calculated =21560.658720674066
# ARIMA (1, 1, 0) + (0, 0, 0, 12)12': AIC Calculated =20939.12516134009
# ARIMA (1, 1, 0) + (0, 0, 1, 12)12': AIC Calculated =20321.68208630507
# ARIMA (1, 1, 0) + (0, 0, 2, 12)12': AIC Calculated =20180.983063360778
# ARIMA (1, 1, 0) + (0, 1, 0, 12)12': AIC Calculated =22634.98180294069
# ARIMA (1, 1, 0) + (0, 1, 1, 12)12': AIC Calculated =20712.363494501573
# ARIMA (1, 1, 0) + (0, 1, 2, 12)12': AIC Calculated =20099.330895964093
# ARIMA (1, 1, 0) + (0, 2, 0, 12)12': AIC Calculated =24550.572551556215
# ARIMA (1, 1, 0) + (0, 2, 1, 12)12': AIC Calculated =22380.69839226264
# ARIMA (1, 1, 0) + (0, 2, 2, 12)12': AIC Calculated =20528.405063249615
# ARIMA (1, 1, 0) + (1, 0, 0, 12)12': AIC Calculated =20396.838885943656
# ARIMA (1, 1, 0) + (1, 0, 1, 12)12': AIC Calculated =20314.883947549126
# ARIMA (1, 1, 0) + (1, 0, 2, 12)12': AIC Calculated =20180.614831738894
# ARIMA (1, 1, 0) + (1, 1, 0, 12)12': AIC Calculated =21399.735114128882
# ARIMA (1, 1, 0) + (1, 1, 1, 12)12': AIC Calculated =20321.24134780468
# ARIMA (1, 1, 0) + (1, 1, 2, 12)12': AIC Calculated =20091.37985230283
# ARIMA (1, 1, 0) + (1, 2, 0, 12)12': AIC Calculated =22848.136224141992
# ARIMA (1, 1, 0) + (1, 2, 1, 12)12': AIC Calculated =21320.08295569931
# ARIMA (1, 1, 0) + (1, 2, 2, 12)12': AIC Calculated =20164.924346241412
# ARIMA (1, 1, 0) + (2, 0, 0, 12)12': AIC Calculated =20184.81932162702
# ARIMA (1, 1, 0) + (2, 0, 1, 12)12': AIC Calculated =20179.217604548357
# ARIMA (1, 1, 0) + (2, 0, 2, 12)12': AIC Calculated =20073.035378661076
# ARIMA (1, 1, 0) + (2, 1, 0, 12)12': AIC Calculated =20839.757862282408
# ARIMA (1, 1, 0) + (2, 1, 1, 12)12': AIC Calculated =20099.789981375674
# ARIMA (1, 1, 0) + (2, 1, 2, 12)12': AIC Calculated =19994.5646584665
# ARIMA (1, 1, 0) + (2, 2, 0, 12)12': AIC Calculated =21923.164657896174
# ARIMA (1, 1, 0) + (2, 2, 1, 12)12': AIC Calculated =20763.533674096303
# ARIMA (1, 1, 0) + (2, 2, 2, 12)12': AIC Calculated =20102.55058702008
# ARIMA (1, 1, 1) + (0, 0, 0, 12)12': AIC Calculated =20174.693206529286
# ARIMA (1, 1, 1) + (0, 0, 1, 12)12': AIC Calculated =19662.776242281878
# ARIMA (1, 1, 1) + (0, 0, 2, 12)12': AIC Calculated =19532.745703614703
# ARIMA (1, 1, 1) + (0, 1, 0, 12)12': AIC Calculated =21770.51731874115
# ARIMA (1, 1, 1) + (0, 1, 1, 12)12': AIC Calculated =20662.825831044378
# ARIMA (1, 1, 1) + (0, 1, 2, 12)12': AIC Calculated =19454.11339888427
# ARIMA (1, 1, 1) + (0, 2, 0, 12)12': AIC Calculated =23607.024924596357
# ARIMA (1, 1, 1) + (0, 2, 1, 12)12': AIC Calculated =21533.59327630076
# ARIMA (1, 1, 1) + (0, 2, 2, 12)12': AIC Calculated =20484.395991763427
# ARIMA (1, 1, 1) + (1, 0, 0, 12)12': AIC Calculated =19769.75563378293
# ARIMA (1, 1, 1) + (1, 0, 1, 12)12': AIC Calculated =19664.77420924489
# ARIMA (1, 1, 1) + (1, 0, 2, 12)12': AIC Calculated =19466.032941547215
# ARIMA (1, 1, 1) + (1, 1, 0, 12)12': AIC Calculated =20786.594747818926
# ARIMA (1, 1, 1) + (1, 1, 1, 12)12': AIC Calculated =19691.84980586287
# ARIMA (1, 1, 1) + (1, 1, 2, 12)12': AIC Calculated =20172.838049312355
# ARIMA (1, 1, 1) + (1, 2, 0, 12)12': AIC Calculated =22637.372015421315
# ARIMA (1, 1, 1) + (1, 2, 1, 12)12': AIC Calculated =20705.881336861363
# ARIMA (1, 1, 1) + (1, 2, 2, 12)12': AIC Calculated =19546.601113905002
# ARIMA (1, 1, 1) + (2, 0, 0, 12)12': AIC Calculated =19542.635464940402
# ARIMA (1, 1, 1) + (2, 0, 1, 12)12': AIC Calculated =19535.57438218304
# ARIMA (1, 1, 1) + (2, 0, 2, 12)12': AIC Calculated =19446.973401199037
# ARIMA (1, 1, 1) + (2, 1, 0, 12)12': AIC Calculated =20196.01682320413
# ARIMA (1, 1, 1) + (2, 1, 1, 12)12': AIC Calculated =19467.365831483337
# ARIMA (1, 1, 1) + (2, 1, 2, 12)12': AIC Calculated =19468.66563958615
# ARIMA (1, 1, 1) + (2, 2, 0, 12)12': AIC Calculated =21366.95525115962
# ARIMA (1, 1, 1) + (2, 2, 1, 12)12': AIC Calculated =20131.377305537895
# ARIMA (1, 1, 1) + (2, 2, 2, 12)12': AIC Calculated =20275.07842176252
# ARIMA (1, 1, 2) + (0, 0, 0, 12)12': AIC Calculated =19925.187592251572
# ARIMA (1, 1, 2) + (0, 0, 1, 12)12': AIC Calculated =19569.486543097468
# ARIMA (1, 1, 2) + (0, 0, 2, 12)12': AIC Calculated =19420.07027776991
# ARIMA (1, 1, 2) + (0, 1, 0, 12)12': AIC Calculated =21330.00620744239
# ARIMA (1, 1, 2) + (0, 1, 1, 12)12': AIC Calculated =19707.7189188975
# ARIMA (1, 1, 2) + (0, 1, 2, 12)12': AIC Calculated =19399.59964665777
# ARIMA (1, 1, 2) + (0, 2, 0, 12)12': AIC Calculated =23025.9116803988
# ARIMA (1, 1, 2) + (0, 2, 1, 12)12': AIC Calculated =21109.688345494476
# ARIMA (1, 1, 2) + (0, 2, 2, 12)12': AIC Calculated =19558.106346138953
# ARIMA (1, 1, 2) + (1, 0, 0, 12)12': AIC Calculated =19673.499630849998
# ARIMA (1, 1, 2) + (1, 0, 1, 12)12': AIC Calculated =19558.56792268154
# ARIMA (1, 1, 2) + (1, 0, 2, 12)12': AIC Calculated =19366.575343788158
# ARIMA (1, 1, 2) + (1, 1, 0, 12)12': AIC Calculated =20571.183707719392
# ARIMA (1, 1, 2) + (1, 1, 1, 12)12': AIC Calculated =19579.24136559401
# ARIMA (1, 1, 2) + (1, 1, 2, 12)12': AIC Calculated =19357.05367761932
# ARIMA (1, 1, 2) + (1, 2, 0, 12)12': AIC Calculated =21891.95626265772
# ARIMA (1, 1, 2) + (1, 2, 1, 12)12': AIC Calculated =20607.336384586124
# ARIMA (1, 1, 2) + (1, 2, 2, 12)12': AIC Calculated =20045.276245562152
# ARIMA (1, 1, 2) + (2, 0, 0, 12)12': AIC Calculated =19451.852588658152
# ARIMA (1, 1, 2) + (2, 0, 1, 12)12': AIC Calculated =19444.780495906158
# ARIMA (1, 1, 2) + (2, 0, 2, 12)12': AIC Calculated =19387.290897681683
# ARIMA (1, 1, 2) + (2, 1, 0, 12)12': AIC Calculated =20073.599484956896
# ARIMA (1, 1, 2) + (2, 1, 1, 12)12': AIC Calculated =19376.641186809073
# ARIMA (1, 1, 2) + (2, 1, 2, 12)12': AIC Calculated =19348.613475244383
# ARIMA (1, 1, 2) + (2, 2, 0, 12)12': AIC Calculated =21812.04445574211
# ARIMA (1, 1, 2) + (2, 2, 1, 12)12': AIC Calculated =21495.075447583964
# ARIMA (1, 1, 2) + (2, 2, 2, 12)12': AIC Calculated =21578.108455590896
# ARIMA (1, 2, 0) + (0, 0, 0, 12)12': AIC Calculated =22160.426658204087
# ARIMA (1, 2, 0) + (0, 0, 1, 12)12': AIC Calculated =21493.478342931216
# ARIMA (1, 2, 0) + (0, 0, 2, 12)12': AIC Calculated =21317.195265114304
# ARIMA (1, 2, 0) + (0, 1, 0, 12)12': AIC Calculated =23903.712522112444
# ARIMA (1, 2, 0) + (0, 1, 1, 12)12': AIC Calculated =21916.345327660074
# ARIMA (1, 2, 0) + (0, 1, 2, 12)12': AIC Calculated =21250.68671454252
# ARIMA (1, 2, 0) + (0, 2, 0, 12)12': AIC Calculated =25870.51744431837
# ARIMA (1, 2, 0) + (0, 2, 1, 12)12': AIC Calculated =23630.121466744393
# ARIMA (1, 2, 0) + (0, 2, 2, 12)12': AIC Calculated =21714.317002245494
# ARIMA (1, 2, 0) + (1, 0, 0, 12)12': AIC Calculated =21443.792845561213
# ARIMA (1, 2, 0) + (1, 0, 1, 12)12': AIC Calculated =21427.688679820443
# ARIMA (1, 2, 0) + (1, 0, 2, 12)12': AIC Calculated =21283.822217331985
# ARIMA (1, 2, 0) + (1, 1, 0, 12)12': AIC Calculated =22370.837572867647
# ARIMA (1, 2, 0) + (1, 1, 1, 12)12': AIC Calculated =21358.193394334587
# ARIMA (1, 2, 0) + (1, 1, 2, 12)12': AIC Calculated =21181.451072688807
# ARIMA (1, 2, 0) + (1, 2, 0, 12)12': AIC Calculated =23833.181445700044
# ARIMA (1, 2, 0) + (1, 2, 1, 12)12': AIC Calculated =22283.097741644102
# ARIMA (1, 2, 0) + (1, 2, 2, 12)12': AIC Calculated =21188.562130153503
# ARIMA (1, 2, 0) + (2, 0, 0, 12)12': AIC Calculated =21282.511783235634
# ARIMA (1, 2, 0) + (2, 0, 1, 12)12': AIC Calculated =21079.646399137855
# ARIMA (1, 2, 0) + (2, 0, 2, 12)12': AIC Calculated =20791.963141875425
# ARIMA (1, 2, 0) + (2, 1, 0, 12)12': AIC Calculated =21799.600842173353
# ARIMA (1, 2, 0) + (2, 1, 1, 12)12': AIC Calculated =21181.193458194146
# ARIMA (1, 2, 0) + (2, 1, 2, 12)12': AIC Calculated =21183.153121597366
# ARIMA (1, 2, 0) + (2, 2, 0, 12)12': AIC Calculated =22764.908318343594
# ARIMA (1, 2, 0) + (2, 2, 1, 12)12': AIC Calculated =21716.810081122647
# ARIMA (1, 2, 0) + (2, 2, 2, 12)12': AIC Calculated =21582.51505642171
# ARIMA (1, 2, 1) + (0, 0, 0, 12)12': AIC Calculated =20925.734213041687
# ARIMA (1, 2, 1) + (0, 0, 1, 12)12': AIC Calculated =20307.079847991226
# ARIMA (1, 2, 1) + (0, 0, 2, 12)12': AIC Calculated =20165.524482106703
# ARIMA (1, 2, 1) + (0, 1, 0, 12)12': AIC Calculated =22618.035802213293
# ARIMA (1, 2, 1) + (0, 1, 1, 12)12': AIC Calculated =20699.379914844536
# ARIMA (1, 2, 1) + (0, 1, 2, 12)12': AIC Calculated =20092.070806732965
# ARIMA (1, 2, 1) + (0, 2, 0, 12)12': AIC Calculated =24529.319354803753
# ARIMA (1, 2, 1) + (0, 2, 1, 12)12': AIC Calculated =22367.353532571447
# ARIMA (1, 2, 1) + (0, 2, 2, 12)12': AIC Calculated =20564.00052841277
# ARIMA (1, 2, 1) + (1, 0, 0, 12)12': AIC Calculated =20394.898400391667
# ARIMA (1, 2, 1) + (1, 0, 1, 12)12': AIC Calculated =20300.071500592538
# ARIMA (1, 2, 1) + (1, 0, 2, 12)12': AIC Calculated =20166.037502204206
# ARIMA (1, 2, 1) + (1, 1, 0, 12)12': AIC Calculated =21396.755491634263
# ARIMA (1, 2, 1) + (1, 1, 1, 12)12': AIC Calculated =20310.476357748412
# ARIMA (1, 2, 1) + (1, 1, 2, 12)12': AIC Calculated =20084.13051111259
# ARIMA (1, 2, 1) + (1, 2, 0, 12)12': AIC Calculated =23844.90732719408
# ARIMA (1, 2, 1) + (1, 2, 1, 12)12': AIC Calculated =21310.037203546442
# ARIMA (1, 2, 1) + (1, 2, 2, 12)12': AIC Calculated =22225.993388238727
# ARIMA (1, 2, 1) + (2, 0, 0, 12)12': AIC Calculated =20182.824724369566
# ARIMA (1, 2, 1) + (2, 0, 1, 12)12': AIC Calculated =20177.15624941063
# ARIMA (1, 2, 1) + (2, 0, 2, 12)12': AIC Calculated =20325.388238315943
# ARIMA (1, 2, 1) + (2, 1, 0, 12)12': AIC Calculated =20837.26433522933
# ARIMA (1, 2, 1) + (2, 1, 1, 12)12': AIC Calculated =20112.254481016476
# ARIMA (1, 2, 1) + (2, 1, 2, 12)12': AIC Calculated =20211.267362874067
# ARIMA (1, 2, 1) + (2, 2, 0, 12)12': AIC Calculated =21919.65845915982
# ARIMA (1, 2, 1) + (2, 2, 1, 12)12': AIC Calculated =22101.111867288797
# ARIMA (1, 2, 1) + (2, 2, 2, 12)12': AIC Calculated =20100.079579211357
# ARIMA (1, 2, 2) + (0, 0, 0, 12)12': AIC Calculated =20876.67875266942
# ARIMA (1, 2, 2) + (0, 0, 1, 12)12': AIC Calculated =20301.733225547883
# ARIMA (1, 2, 2) + (0, 0, 2, 12)12': AIC Calculated =20167.819519224555
# ARIMA (1, 2, 2) + (0, 1, 0, 12)12': AIC Calculated =22388.12032896656
# ARIMA (1, 2, 2) + (0, 1, 1, 12)12': AIC Calculated =20649.20142126982
# ARIMA (1, 2, 2) + (0, 1, 2, 12)12': AIC Calculated =21293.27514387627
# ARIMA (1, 2, 2) + (0, 2, 0, 12)12': AIC Calculated =24213.4718697106
# ARIMA (1, 2, 2) + (0, 2, 1, 12)12': AIC Calculated =23613.570358493875
# ARIMA (1, 2, 2) + (0, 2, 2, 12)12': AIC Calculated =20494.19187902425
# ARIMA (1, 2, 2) + (1, 0, 0, 12)12': AIC Calculated =20340.734015249716
# ARIMA (1, 2, 2) + (1, 0, 1, 12)12': AIC Calculated =20309.008957342412
# ARIMA (1, 2, 2) + (1, 0, 2, 12)12': AIC Calculated =20159.38646489941
# ARIMA (1, 2, 2) + (1, 1, 0, 12)12': AIC Calculated =21289.735131266665
# ARIMA (1, 2, 2) + (1, 1, 1, 12)12': AIC Calculated =21754.210209510795
# ARIMA (1, 2, 2) + (1, 1, 2, 12)12': AIC Calculated =21614.015770158643
# ARIMA (1, 2, 2) + (1, 2, 0, 12)12': AIC Calculated =22633.377045267098
# ARIMA (1, 2, 2) + (1, 2, 1, 12)12': AIC Calculated =21082.856844743503
# ARIMA (1, 2, 2) + (1, 2, 2, 12)12': AIC Calculated =23456.46444535216
# ARIMA (1, 2, 2) + (2, 0, 0, 12)12': AIC Calculated =20196.367676796188
# ARIMA (1, 2, 2) + (2, 0, 1, 12)12': AIC Calculated =20191.57582512361
# ARIMA (1, 2, 2) + (2, 0, 2, 12)12': AIC Calculated =20167.544003248207
# ARIMA (1, 2, 2) + (2, 1, 0, 12)12': AIC Calculated =21542.884772351914
# ARIMA (1, 2, 2) + (2, 1, 1, 12)12': AIC Calculated =21679.313687402424
# ARIMA (1, 2, 2) + (2, 1, 2, 12)12': AIC Calculated =21654.14037155796
# ARIMA (1, 2, 2) + (2, 2, 0, 12)12': AIC Calculated =21430.247068595214
# ARIMA (1, 2, 2) + (2, 2, 1, 12)12': AIC Calculated =23566.641119574477
# ARIMA (1, 2, 2) + (2, 2, 2, 12)12': AIC Calculated =20752.649522440995
# ARIMA (2, 0, 0) + (0, 0, 0, 12)12': AIC Calculated =20718.510500255856
# ARIMA (2, 0, 0) + (0, 0, 1, 12)12': AIC Calculated =20295.151637137933
# ARIMA (2, 0, 0) + (0, 0, 2, 12)12': AIC Calculated =20149.09654352723
# ARIMA (2, 0, 0) + (0, 1, 0, 12)12': AIC Calculated =21353.73437673621
# ARIMA (2, 0, 0) + (0, 1, 1, 12)12': AIC Calculated =19743.94008203326
# ARIMA (2, 0, 0) + (0, 1, 2, 12)12': AIC Calculated =19429.462845616617
# ARIMA (2, 0, 0) + (0, 2, 0, 12)12': AIC Calculated =23105.72201195429
# ARIMA (2, 0, 0) + (0, 2, 1, 12)12': AIC Calculated =21130.522700990718
# ARIMA (2, 0, 0) + (0, 2, 2, 12)12': AIC Calculated =19577.904009502767
# ARIMA (2, 0, 0) + (1, 0, 0, 12)12': AIC Calculated =20308.45283629927
# ARIMA (2, 0, 0) + (1, 0, 1, 12)12': AIC Calculated =20272.62986900765
# ARIMA (2, 0, 0) + (1, 0, 2, 12)12': AIC Calculated =20149.750858143314
# ARIMA (2, 0, 0) + (1, 1, 0, 12)12': AIC Calculated =20462.62623581828
# ARIMA (2, 0, 0) + (1, 1, 1, 12)12': AIC Calculated =19590.749740502357
# ARIMA (2, 0, 0) + (1, 1, 2, 12)12': AIC Calculated =19430.591477322065
# ARIMA (2, 0, 0) + (1, 2, 0, 12)12': AIC Calculated =21788.65894735948
# ARIMA (2, 0, 0) + (1, 2, 1, 12)12': AIC Calculated =20390.256977179688
# ARIMA (2, 0, 0) + (1, 2, 2, 12)12': AIC Calculated =19444.626828477878
# ARIMA (2, 0, 0) + (2, 0, 0, 12)12': AIC Calculated =20313.848220492422
# ARIMA (2, 0, 0) + (2, 0, 1, 12)12': AIC Calculated =19626.851978471892
# ARIMA (2, 0, 0) + (2, 0, 2, 12)12': AIC Calculated =19621.910570226362
# ARIMA (2, 0, 0) + (2, 1, 0, 12)12': AIC Calculated =20044.684389950227
# ARIMA (2, 0, 0) + (2, 1, 1, 12)12': AIC Calculated =19425.453740845496
# ARIMA (2, 0, 0) + (2, 1, 2, 12)12': AIC Calculated =19421.492712300736
# ARIMA (2, 0, 0) + (2, 2, 0, 12)12': AIC Calculated =20995.40356081206
# ARIMA (2, 0, 0) + (2, 2, 1, 12)12': AIC Calculated =19971.76652450153
# ARIMA (2, 0, 0) + (2, 2, 2, 12)12': AIC Calculated =19956.81305444167
# ARIMA (2, 0, 1) + (0, 0, 0, 12)12': AIC Calculated =20720.3611370099
# ARIMA (2, 0, 1) + (0, 0, 1, 12)12': AIC Calculated =20281.863747662992
# ARIMA (2, 0, 1) + (0, 0, 2, 12)12': AIC Calculated =20137.304192246018
# ARIMA (2, 0, 1) + (0, 1, 0, 12)12': AIC Calculated =21175.81423238179
# ARIMA (2, 0, 1) + (0, 1, 1, 12)12': AIC Calculated =19686.491491082965
# ARIMA (2, 0, 1) + (0, 1, 2, 12)12': AIC Calculated =19418.072270328295
# ARIMA (2, 0, 1) + (0, 2, 0, 12)12': AIC Calculated =22832.864141763002
# ARIMA (2, 0, 1) + (0, 2, 1, 12)12': AIC Calculated =20943.665145814783
# ARIMA (2, 0, 1) + (0, 2, 2, 12)12': AIC Calculated =19543.58962760307
# ARIMA (2, 0, 1) + (1, 0, 0, 12)12': AIC Calculated =20308.66048373157
# ARIMA (2, 0, 1) + (1, 0, 1, 12)12': AIC Calculated =20661.426385060546
# ARIMA (2, 0, 1) + (1, 0, 2, 12)12': AIC Calculated =28758.418713918873
# ARIMA (2, 0, 1) + (1, 1, 0, 12)12': AIC Calculated =20370.13123699597
# ARIMA (2, 0, 1) + (1, 1, 1, 12)12': AIC Calculated =19580.416195006997
# ARIMA (2, 0, 1) + (1, 1, 2, 12)12': AIC Calculated =19412.77679472269
# ARIMA (2, 0, 1) + (1, 2, 0, 12)12': AIC Calculated =21792.930277723422
# ARIMA (2, 0, 1) + (1, 2, 1, 12)12': AIC Calculated =20298.521157454197
# ARIMA (2, 0, 1) + (1, 2, 2, 12)12': AIC Calculated =19884.976806415565
# ARIMA (2, 0, 1) + (2, 0, 0, 12)12': AIC Calculated =20177.11000626878
# ARIMA (2, 0, 1) + (2, 0, 1, 12)12': AIC Calculated =33438.59985132744
# ARIMA (2, 0, 1) + (2, 0, 2, 12)12': AIC Calculated =33732.93165151014
# ARIMA (2, 0, 1) + (2, 1, 0, 12)12': AIC Calculated =19990.63942985541
# ARIMA (2, 0, 1) + (2, 1, 1, 12)12': AIC Calculated =19408.665437752963
# ARIMA (2, 0, 1) + (2, 1, 2, 12)12': AIC Calculated =19415.79416635816
# ARIMA (2, 0, 1) + (2, 2, 0, 12)12': AIC Calculated =20820.726832144395
# ARIMA (2, 0, 1) + (2, 2, 1, 12)12': AIC Calculated =19917.389600332863
# ARIMA (2, 0, 1) + (2, 2, 2, 12)12': AIC Calculated =20997.687393724933
# ARIMA (2, 0, 2) + (0, 0, 0, 12)12': AIC Calculated =19983.80364509432
# ARIMA (2, 0, 2) + (0, 0, 1, 12)12': AIC Calculated =19663.72358961249
# ARIMA (2, 0, 2) + (0, 0, 2, 12)12': AIC Calculated =19543.45491713859
# ARIMA (2, 0, 2) + (0, 1, 0, 12)12': AIC Calculated =20637.774668532853
# ARIMA (2, 0, 2) + (0, 1, 1, 12)12': AIC Calculated =19449.13627373263
# ARIMA (2, 0, 2) + (0, 1, 2, 12)12': AIC Calculated =19307.81395359576
# ARIMA (2, 0, 2) + (0, 2, 0, 12)12': AIC Calculated =22062.959222224516
# ARIMA (2, 0, 2) + (0, 2, 1, 12)12': AIC Calculated =20418.9662268219
# ARIMA (2, 0, 2) + (0, 2, 2, 12)12': AIC Calculated =19526.853012498737
# ARIMA (2, 0, 2) + (1, 0, 0, 12)12': AIC Calculated =19753.813478969347
# ARIMA (2, 0, 2) + (1, 0, 1, 12)12': AIC Calculated =19680.30952776816
# ARIMA (2, 0, 2) + (1, 0, 2, 12)12': AIC Calculated =19549.83529856853
# ARIMA (2, 0, 2) + (1, 1, 0, 12)12': AIC Calculated =20327.155884886917
# ARIMA (2, 0, 2) + (1, 1, 1, 12)12': AIC Calculated =19588.313842258685
# ARIMA (2, 0, 2) + (1, 1, 2, 12)12': AIC Calculated =19259.99009987392
# ARIMA (2, 0, 2) + (1, 2, 0, 12)12': AIC Calculated =21463.483593287783
# ARIMA (2, 0, 2) + (1, 2, 1, 12)12': AIC Calculated =20247.05032537434
# ARIMA (2, 0, 2) + (1, 2, 2, 12)12': AIC Calculated =20946.502801101444
# ARIMA (2, 0, 2) + (2, 0, 0, 12)12': AIC Calculated =19557.0411400381
# ARIMA (2, 0, 2) + (2, 0, 1, 12)12': AIC Calculated =19549.832097617385
# ARIMA (2, 0, 2) + (2, 0, 2, 12)12': AIC Calculated =19542.888415792586
# ARIMA (2, 0, 2) + (2, 1, 0, 12)12': AIC Calculated =19937.000950103815
# ARIMA (2, 0, 2) + (2, 1, 1, 12)12': AIC Calculated =19807.991277986803
# ARIMA (2, 0, 2) + (2, 1, 2, 12)12': AIC Calculated =19821.84818422208
# ARIMA (2, 0, 2) + (2, 2, 0, 12)12': AIC Calculated =20615.080261870855
# ARIMA (2, 0, 2) + (2, 2, 1, 12)12': AIC Calculated =21060.49637155987
# ARIMA (2, 0, 2) + (2, 2, 2, 12)12': AIC Calculated =21021.841279165958
# ARIMA (2, 1, 0) + (0, 0, 0, 12)12': AIC Calculated =20421.44120246299
# ARIMA (2, 1, 0) + (0, 0, 1, 12)12': AIC Calculated =20107.003883241363
# ARIMA (2, 1, 0) + (0, 0, 2, 12)12': AIC Calculated =19889.418618024887
# ARIMA (2, 1, 0) + (0, 1, 0, 12)12': AIC Calculated =21692.90166389991
# ARIMA (2, 1, 0) + (0, 1, 1, 12)12': AIC Calculated =20213.93607878637
# ARIMA (2, 1, 0) + (0, 1, 2, 12)12': AIC Calculated =19893.412056424713
# ARIMA (2, 1, 0) + (0, 2, 0, 12)12': AIC Calculated =23265.307457311384
# ARIMA (2, 1, 0) + (0, 2, 1, 12)12': AIC Calculated =21465.548885652606
# ARIMA (2, 1, 0) + (0, 2, 2, 12)12': AIC Calculated =20045.737508322636
# ARIMA (2, 1, 0) + (1, 0, 0, 12)12': AIC Calculated =20205.861223655244
# ARIMA (2, 1, 0) + (1, 0, 1, 12)12': AIC Calculated =20069.439296522523
# ARIMA (2, 1, 0) + (1, 0, 2, 12)12': AIC Calculated =19855.800886486315
# ARIMA (2, 1, 0) + (1, 1, 0, 12)12': AIC Calculated =21152.59220765806
# ARIMA (2, 1, 0) + (1, 1, 1, 12)12': AIC Calculated =20132.024629032854
# ARIMA (2, 1, 0) + (1, 1, 2, 12)12': AIC Calculated =20051.77247592981
# ARIMA (2, 1, 0) + (1, 2, 0, 12)12': AIC Calculated =22454.23119235751
# ARIMA (2, 1, 0) + (1, 2, 1, 12)12': AIC Calculated =21073.505964693737
# ARIMA (2, 1, 0) + (1, 2, 2, 12)12': AIC Calculated =19991.19295386893
# ARIMA (2, 1, 0) + (2, 0, 0, 12)12': AIC Calculated =19799.605095597533
# ARIMA (2, 1, 0) + (2, 0, 1, 12)12': AIC Calculated =19797.75944134728
# ARIMA (2, 1, 0) + (2, 0, 2, 12)12': AIC Calculated =19159.79640552385
# ARIMA (2, 1, 0) + (2, 1, 0, 12)12': AIC Calculated =20366.931884677935
# ARIMA (2, 1, 0) + (2, 1, 1, 12)12': AIC Calculated =19724.770644219294
# ARIMA (2, 1, 0) + (2, 1, 2, 12)12': AIC Calculated =19869.94929590761
# ARIMA (2, 1, 0) + (2, 2, 0, 12)12': AIC Calculated =21588.252123166392
# ARIMA (2, 1, 0) + (2, 2, 1, 12)12': AIC Calculated =20294.524616173978
# ARIMA (2, 1, 0) + (2, 2, 2, 12)12': AIC Calculated =19733.459710672883
# ARIMA (2, 1, 1) + (0, 0, 0, 12)12': AIC Calculated =19926.656370042358
# ARIMA (2, 1, 1) + (0, 0, 1, 12)12': AIC Calculated =19557.75879482324
# ARIMA (2, 1, 1) + (0, 0, 2, 12)12': AIC Calculated =19411.96347698288
# ARIMA (2, 1, 1) + (0, 1, 0, 12)12': AIC Calculated =21680.36423941533
# ARIMA (2, 1, 1) + (0, 1, 1, 12)12': AIC Calculated =19714.53091071661
# ARIMA (2, 1, 1) + (0, 1, 2, 12)12': AIC Calculated =19352.32495059899
# ARIMA (2, 1, 1) + (0, 2, 0, 12)12': AIC Calculated =23238.639847837512
# ARIMA (2, 1, 1) + (0, 2, 1, 12)12': AIC Calculated =21120.252800145332
# ARIMA (2, 1, 1) + (0, 2, 2, 12)12': AIC Calculated =19559.81635150939
# ARIMA (2, 1, 1) + (1, 0, 0, 12)12': AIC Calculated =19628.869376338873
# ARIMA (2, 1, 1) + (1, 0, 1, 12)12': AIC Calculated =19546.684014478462
# ARIMA (2, 1, 1) + (1, 0, 2, 12)12': AIC Calculated =19357.92520176745
# ARIMA (2, 1, 1) + (1, 1, 0, 12)12': AIC Calculated =20460.85182453411
# ARIMA (2, 1, 1) + (1, 1, 1, 12)12': AIC Calculated =19562.84472962277
# ARIMA (2, 1, 1) + (1, 1, 2, 12)12': AIC Calculated =19349.104957637523
# ARIMA (2, 1, 1) + (1, 2, 0, 12)12': AIC Calculated =21785.426715294612
# ARIMA (2, 1, 1) + (1, 2, 1, 12)12': AIC Calculated =20394.07720629018
# ARIMA (2, 1, 1) + (1, 2, 2, 12)12': AIC Calculated =20096.669072467215
# ARIMA (2, 1, 1) + (2, 0, 0, 12)12': AIC Calculated =19433.84445665966
# ARIMA (2, 1, 1) + (2, 0, 1, 12)12': AIC Calculated =19415.541396519402
# ARIMA (2, 1, 1) + (2, 0, 2, 12)12': AIC Calculated =19359.6943961141
# ARIMA (2, 1, 1) + (2, 1, 0, 12)12': AIC Calculated =20042.70550910491
# ARIMA (2, 1, 1) + (2, 1, 1, 12)12': AIC Calculated =19359.369549561896
# ARIMA (2, 1, 1) + (2, 1, 2, 12)12': AIC Calculated =19315.295833919863
# ARIMA (2, 1, 1) + (2, 2, 0, 12)12': AIC Calculated =20993.489353243847
# ARIMA (2, 1, 1) + (2, 2, 1, 12)12': AIC Calculated =20675.370919671197
# ARIMA (2, 1, 1) + (2, 2, 2, 12)12': AIC Calculated =21254.811083543875
# ARIMA (2, 1, 2) + (0, 0, 0, 12)12': AIC Calculated =19874.46478068281
# ARIMA (2, 1, 2) + (0, 0, 1, 12)12': AIC Calculated =19453.74759859356
# ARIMA (2, 1, 2) + (0, 0, 2, 12)12': AIC Calculated =19336.385109749408
# ARIMA (2, 1, 2) + (0, 1, 0, 12)12': AIC Calculated =21161.470666357585
# ARIMA (2, 1, 2) + (0, 1, 1, 12)12': AIC Calculated =19659.429462772256
# ARIMA (2, 1, 2) + (0, 1, 2, 12)12': AIC Calculated =19381.595332909194
# ARIMA (2, 1, 2) + (0, 2, 0, 12)12': AIC Calculated =22957.71482155945
# ARIMA (2, 1, 2) + (0, 2, 1, 12)12': AIC Calculated =20932.14328755695
# ARIMA (2, 1, 2) + (0, 2, 2, 12)12': AIC Calculated =21080.010624246697
# ARIMA (2, 1, 2) + (1, 0, 0, 12)12': AIC Calculated =19493.70117980164
# ARIMA (2, 1, 2) + (1, 0, 1, 12)12': AIC Calculated =19454.874000511896
# ARIMA (2, 1, 2) + (1, 0, 2, 12)12': AIC Calculated =19293.717624307043
# ARIMA (2, 1, 2) + (1, 1, 0, 12)12': AIC Calculated =20323.416311239216
# ARIMA (2, 1, 2) + (1, 1, 1, 12)12': AIC Calculated =19407.863504485173
# ARIMA (2, 1, 2) + (1, 1, 2, 12)12': AIC Calculated =19692.76173783298
# ARIMA (2, 1, 2) + (1, 2, 0, 12)12': AIC Calculated =21712.889117603707
# ARIMA (2, 1, 2) + (1, 2, 1, 12)12': AIC Calculated =20410.172162831812
# ARIMA (2, 1, 2) + (1, 2, 2, 12)12': AIC Calculated =21086.706666292157
# ARIMA (2, 1, 2) + (2, 0, 0, 12)12': AIC Calculated =19427.046876991582
# ARIMA (2, 1, 2) + (2, 0, 1, 12)12': AIC Calculated =19415.973122824136
# ARIMA (2, 1, 2) + (2, 0, 2, 12)12': AIC Calculated =19081.67001791967
# ARIMA (2, 1, 2) + (2, 1, 0, 12)12': AIC Calculated =20028.63069346613
# ARIMA (2, 1, 2) + (2, 1, 1, 12)12': AIC Calculated =19510.097321079906
# ARIMA (2, 1, 2) + (2, 1, 2, 12)12': AIC Calculated =19167.09234936515
# ARIMA (2, 1, 2) + (2, 2, 0, 12)12': AIC Calculated =21723.337428937106
# ARIMA (2, 1, 2) + (2, 2, 1, 12)12': AIC Calculated =20214.17399802676
# ARIMA (2, 1, 2) + (2, 2, 2, 12)12': AIC Calculated =19806.183439844768
# ARIMA (2, 2, 0) + (0, 0, 0, 12)12': AIC Calculated =21344.350264914192
# ARIMA (2, 2, 0) + (0, 0, 1, 12)12': AIC Calculated =21056.545620260258
# ARIMA (2, 2, 0) + (0, 0, 2, 12)12': AIC Calculated =20888.250373395036
# ARIMA (2, 2, 0) + (0, 1, 0, 12)12': AIC Calculated =22493.067192963474
# ARIMA (2, 2, 0) + (0, 1, 1, 12)12': AIC Calculated =21125.82149578853
# ARIMA (2, 2, 0) + (0, 1, 2, 12)12': AIC Calculated =20823.947406062078
# ARIMA (2, 2, 0) + (0, 2, 0, 12)12': AIC Calculated =24033.1246973414
# ARIMA (2, 2, 0) + (0, 2, 1, 12)12': AIC Calculated =22257.318766243072
# ARIMA (2, 2, 0) + (0, 2, 2, 12)12': AIC Calculated =20944.673830519947
# ARIMA (2, 2, 0) + (1, 0, 0, 12)12': AIC Calculated =21121.031765543987
# ARIMA (2, 2, 0) + (1, 0, 1, 12)12': AIC Calculated =21025.66339215101
# ARIMA (2, 2, 0) + (1, 0, 2, 12)12': AIC Calculated =20845.66485706902
# ARIMA (2, 2, 0) + (1, 1, 0, 12)12': AIC Calculated =21998.73086894663
# ARIMA (2, 2, 0) + (1, 1, 1, 12)12': AIC Calculated =21037.38220490153
# ARIMA (2, 2, 0) + (1, 1, 2, 12)12': AIC Calculated =20964.873622760373
# ARIMA (2, 2, 0) + (1, 2, 0, 12)12': AIC Calculated =23232.857167340037
# ARIMA (2, 2, 0) + (1, 2, 1, 12)12': AIC Calculated =21916.067027738434
# ARIMA (2, 2, 0) + (1, 2, 2, 12)12': AIC Calculated =20904.337641025653
# ARIMA (2, 2, 0) + (2, 0, 0, 12)12': AIC Calculated =20905.996440182742
# ARIMA (2, 2, 0) + (2, 0, 1, 12)12': AIC Calculated =20877.984223265757
# ARIMA (2, 2, 0) + (2, 0, 2, 12)12': AIC Calculated =20836.450103488314
# ARIMA (2, 2, 0) + (2, 1, 0, 12)12': AIC Calculated =21527.922144025302
# ARIMA (2, 2, 0) + (2, 1, 1, 12)12': AIC Calculated =20818.340926988523
# ARIMA (2, 2, 0) + (2, 1, 2, 12)12': AIC Calculated =20767.594161781974
# ARIMA (2, 2, 0) + (2, 2, 0, 12)12': AIC Calculated =22536.702825734108
# ARIMA (2, 2, 0) + (2, 2, 1, 12)12': AIC Calculated =21444.229396174527
# ARIMA (2, 2, 0) + (2, 2, 2, 12)12': AIC Calculated =20815.890976427225
# ARIMA (2, 2, 1) + (0, 0, 0, 12)12': AIC Calculated =20420.07862596371
# ARIMA (2, 2, 1) + (0, 0, 1, 12)12': AIC Calculated =20091.154401470427
# ARIMA (2, 2, 1) + (0, 0, 2, 12)12': AIC Calculated =19874.471074061657
# ARIMA (2, 2, 1) + (0, 1, 0, 12)12': AIC Calculated =21690.125101199676
# ARIMA (2, 2, 1) + (0, 1, 1, 12)12': AIC Calculated =20197.921943675166
# ARIMA (2, 2, 1) + (0, 1, 2, 12)12': AIC Calculated =19886.18441983938
# ARIMA (2, 2, 1) + (0, 2, 0, 12)12': AIC Calculated =23259.59670161055
# ARIMA (2, 2, 1) + (0, 2, 1, 12)12': AIC Calculated =21452.157402880133
# ARIMA (2, 2, 1) + (0, 2, 2, 12)12': AIC Calculated =20040.550608880978
# ARIMA (2, 2, 1) + (1, 0, 0, 12)12': AIC Calculated =20201.085631061447
# ARIMA (2, 2, 1) + (1, 0, 1, 12)12': AIC Calculated =20066.985472715387
# ARIMA (2, 2, 1) + (1, 0, 2, 12)12': AIC Calculated =19847.615698488757
# ARIMA (2, 2, 1) + (1, 1, 0, 12)12': AIC Calculated =21146.75042073409
# ARIMA (2, 2, 1) + (1, 1, 1, 12)12': AIC Calculated =20130.952588461412
# ARIMA (2, 2, 1) + (1, 1, 2, 12)12': AIC Calculated =20043.062276839843
# ARIMA (2, 2, 1) + (1, 2, 0, 12)12': AIC Calculated =22449.683539344755
# ARIMA (2, 2, 1) + (1, 2, 1, 12)12': AIC Calculated =21075.648269044555
# ARIMA (2, 2, 1) + (1, 2, 2, 12)12': AIC Calculated =21992.153795413637
# ARIMA (2, 2, 1) + (2, 0, 0, 12)12': AIC Calculated =19797.981048801783
# ARIMA (2, 2, 1) + (2, 0, 1, 12)12': AIC Calculated =19796.08085200098
# ARIMA (2, 2, 1) + (2, 0, 2, 12)12': AIC Calculated =19817.05945254598
# ARIMA (2, 2, 1) + (2, 1, 0, 12)12': AIC Calculated =20365.074574110527
# ARIMA (2, 2, 1) + (2, 1, 1, 12)12': AIC Calculated =19729.341348987862
# ARIMA (2, 2, 1) + (2, 1, 2, 12)12': AIC Calculated =19878.15862759212
# ARIMA (2, 2, 1) + (2, 2, 0, 12)12': AIC Calculated =21585.50907232158
# ARIMA (2, 2, 1) + (2, 2, 1, 12)12': AIC Calculated =20299.419851218103
# ARIMA (2, 2, 1) + (2, 2, 2, 12)12': AIC Calculated =20737.70464124242
# ARIMA (2, 2, 2) + (0, 0, 0, 12)12': AIC Calculated =20291.44812881688
# ARIMA (2, 2, 2) + (0, 0, 1, 12)12': AIC Calculated =19969.005400383816
# ARIMA (2, 2, 2) + (0, 0, 2, 12)12': AIC Calculated =19902.94602169428
# ARIMA (2, 2, 2) + (0, 1, 0, 12)12': AIC Calculated =21345.880118157773
# ARIMA (2, 2, 2) + (0, 1, 1, 12)12': AIC Calculated =20662.096474685262
# ARIMA (2, 2, 2) + (0, 1, 2, 12)12': AIC Calculated =20769.19567422945
# ARIMA (2, 2, 2) + (0, 2, 0, 12)12': AIC Calculated =23219.539012746805
# ARIMA (2, 2, 2) + (0, 2, 1, 12)12': AIC Calculated =22170.949551783087
# ARIMA (2, 2, 2) + (0, 2, 2, 12)12': AIC Calculated =22145.18146831289
# ARIMA (2, 2, 2) + (1, 0, 0, 12)12': AIC Calculated =20089.893868406354
# ARIMA (2, 2, 2) + (1, 0, 1, 12)12': AIC Calculated =20046.217308202442
# ARIMA (2, 2, 2) + (1, 0, 2, 12)12': AIC Calculated =19905.563357582767
# ARIMA (2, 2, 2) + (1, 1, 0, 12)12': AIC Calculated =21172.228570996318
# ARIMA (2, 2, 2) + (1, 1, 1, 12)12': AIC Calculated =20933.720461425444
# ARIMA (2, 2, 2) + (1, 1, 2, 12)12': AIC Calculated =20795.952244018154
# ARIMA (2, 2, 2) + (1, 2, 0, 12)12': AIC Calculated =22636.231637518395
# ARIMA (2, 2, 2) + (1, 2, 1, 12)12': AIC Calculated =22361.963886269277
# ARIMA (2, 2, 2) + (1, 2, 2, 12)12': AIC Calculated =22151.66944267459
# ARIMA (2, 2, 2) + (2, 0, 0, 12)12': AIC Calculated =19922.426265246668
# ARIMA (2, 2, 2) + (2, 0, 1, 12)12': AIC Calculated =19927.149881435136
# ARIMA (2, 2, 2) + (2, 0, 2, 12)12': AIC Calculated =19902.330692239797
# ARIMA (2, 2, 2) + (2, 1, 0, 12)12': AIC Calculated =20284.12116845652
# ARIMA (2, 2, 2) + (2, 1, 1, 12)12': AIC Calculated =20794.826396657707
# ARIMA (2, 2, 2) + (2, 1, 2, 12)12': AIC Calculated =20772.375491199353
# ARIMA (2, 2, 2) + (2, 2, 0, 12)12': AIC Calculated =21852.207258895945
# ARIMA (2, 2, 2) + (2, 2, 1, 12)12': AIC Calculated =22176.71676977155
# ARIMA (2, 2, 2) + (2, 2, 2, 12)12': AIC Calculated =22137.606346965367

# %%
ans_df.loc[ans_df['aic'].idxmin()]
# Out:
# pdq         (2, 1, 2)
# pdqs    (2, 0, 2, 12)
# aic      19081.670018
# Name: 641, dtype: object

# %%
ARIMA_Model = sm.tsa.statespace.SARIMAX(train,
                                            order= (2, 1, 2),
                                            seasonal_order= (2, 0, 2, 12),
                                            enforce_invertibility=False,
                                            enforce_stationarity=False)
output = ARIMA_Model.fit()
print(output.summary().tables[1])
output.plot_diagnostics(figsize=(15,18))
plt.show()
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.1101      0.047     23.828      0.000       1.019       1.201
# ar.L2         -0.7069      0.043    -16.518      0.000      -0.791      -0.623
# ma.L1         -1.5205      0.058    -26.365      0.000      -1.634      -1.407
# ma.L2          0.6465      0.056     11.589      0.000       0.537       0.756
# ar.S.L12      -1.8019      0.003   -579.983      0.000      -1.808      -1.796
# ar.S.L24      -0.9999      0.003   -345.808      0.000      -1.006      -0.994
# ma.S.L12       1.7712      0.032     55.950      0.000       1.709       1.833
# ma.S.L24       0.9649      0.034     28.512      0.000       0.899       1.031
# sigma2      6346.5210    316.468     20.054      0.000    5726.254    6966.788
# ==============================================================================

# %%
forecast = output.predict(0,(train.shape[0])-1).to_frame(name="forecast")
forecast
#forecast = inv_boxcox(forecast, lam)
forecast["date"]=train.index

forecast = forecast.set_index('date')
arima_rmse = mean_squared_error(train, forecast, squared=False)
plot_forecast(forecast, 'ARIMA Model', arima_rmse)

# %%
forecast = output.predict(0,(valid.shape[0])-1, dynamic= False).to_frame(name="forecast")
forecast
#forecast = inv_boxcox(forecast, lam)
forecast["date"]=valid.index

forecast = forecast.set_index('date')
arima_rmse = mean_squared_error(valid, forecast, squared=False)
plot_forecast(forecast, 'ARIMA Model', arima_rmse)

# %%
forecast = output.forecast(92).to_frame(name="forecast")
forecast
#forecast = inv_boxcox(forecast, lam)
forecast["date"]=valid.index

forecast = forecast.set_index('date')
arima_rmse = mean_squared_error(valid, forecast, squared=False)
plot_forecast(forecast, 'ARIMA Model', arima_rmse)

# %%
forecast['valid']=valid['transactions_6']
forecast['forecast']=forecast['forecast'].astype(int)
forecast
# Out:
#             forecast  valid
# date
# 2023-03-31       194    270
# 2023-04-01        38      1
# 2023-04-02        34      0
# 2023-04-03       166    117
# 2023-04-04       158    132
# ...              ...    ...
# 2023-06-26       199    194
# 2023-06-27       144    192
# 2023-06-28        78    172
# 2023-06-29       166    250
# 2023-06-30       201    305
#
# [92 rows x 2 columns]

# %%
forecast['ecart']=forecast['forecast']-valid['transactions_6']

# %%
forecast = output.forecast(30).to_frame(name="forecast")
forecast
#forecast = inv_boxcox(forecast, lam)
forecast["date"]=valid.head(30).index

forecast = forecast.set_index('date')
#arima_rmse = mean_squared_error(forecast, squared=False)
plot_forecast(forecast, 'ARIMA Model', 2)

# %%
forecast = output.forecast(30).to_frame(name="forecast")
forecast
# Out:
#               forecast
# 2023-03-31  194.257579
# 2023-04-01   38.194821
# 2023-04-02   34.442937
# 2023-04-03  166.400403
# 2023-04-04  158.115874
# 2023-04-05  116.712303
# 2023-04-06  199.091557
# 2023-04-07  210.646329
# 2023-04-08   87.657470
# 2023-04-09   80.119060
# 2023-04-10  189.745086
# 2023-04-11  149.597669
# 2023-04-12   79.282557
# 2023-04-13  157.460768
# 2023-04-14  192.062399
# 2023-04-15   97.131006
# 2023-04-16   99.210876
# 2023-04-17  182.399248
# 2023-04-18  133.266297
# 2023-04-19   62.829722
# 2023-04-20  146.507995
# 2023-04-21  191.481983
# 2023-04-22   86.145727
# 2023-04-23   89.430101
# 2023-04-24  189.397916
# 2023-04-25  145.049889
# 2023-04-26   72.315364
# 2023-04-27  137.817214
# 2023-04-28  181.637989
# 2023-04-29   98.092714

# %%
valid
# Out:
#             transactions_6
# Date
# 2023-03-31             270
# 2023-04-01               1
# 2023-04-02               0
# 2023-04-03             117
# 2023-04-04             132
# ...                    ...
# 2023-06-26             194
# 2023-06-27             192
# 2023-06-28             172
# 2023-06-29             250
# 2023-06-30             305
#
# [92 rows x 1 columns]

# %%
# Out:
#            forecast
# 2023-06-30      NaN
# 2023-07-01      NaN
# 2023-07-02      NaN
# 2023-07-03      NaN
# 2023-07-04      NaN
# 2023-07-05      NaN
# 2023-07-06      NaN
# 2023-07-07      NaN
# 2023-07-08      NaN
# 2023-07-09      NaN
# 2023-07-10      NaN
# 2023-07-11      NaN
# 2023-07-12      NaN
# 2023-07-13      NaN
# 2023-07-14      NaN
# 2023-07-15      NaN
# 2023-07-16      NaN
# 2023-07-17      NaN
# 2023-07-18      NaN
# 2023-07-19      NaN
# 2023-07-20      NaN
# 2023-07-21      NaN
# 2023-07-22      NaN
# 2023-07-23      NaN
# 2023-07-24      NaN
# 2023-07-25      NaN
# 2023-07-26      NaN
# 2023-07-27      NaN
# 2023-07-28      NaN
# 2023-07-29      NaN
